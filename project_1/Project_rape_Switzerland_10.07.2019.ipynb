# %%
from tika import parser
import glob

# %%
parsedPDF=parser.from_file('C:/Users/Dominik Balmer/Documents/LEDE_2019/data-studio-projects/pdf_Obergericht/SB170139-O1.pdf')
#parsedPDF['content'][11]
parsedPDF['metadata']['title']
parsedPDF['metadata']['date']
parsedPDF['metadata']['creator']
# Out:
# 'lic.iur. B. Stiefel'

# %%
parsedPDF
# Out:
# {'status': 200,
#  'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDispositiv allgemein SB\n\n\nObergericht des Kantons Zürich \nII. Strafkammer    \n \n\n \n\n \n \n\nGeschäfts-Nr.: SB170139-O/U/ad \n \n\nMitwirkend: die Oberrichter Dr. Bussmann, Präsident, lic. iur. Stiefel und die \n\nOberrichterin lic. iur. Bertschi sowie die Gerichtsschreiberin \n\nlic. iur. Neukom \n\n \n\nUrteil vom 8. September 2017 \n\n \n\nin Sachen \n\n \n\nA._____,  \n\nBeschuldigter, Berufungskläger und Anschlussberufungsbeklagter \n\n \n\namtlich verteidigt durch Rechtsanwalt lic. iur. X._____ \n\n \n\ngegen \n\n \n\nStaatsanwaltschaft IV des Kantons Zürich,  \n\nAnklägerin und Berufungsbeklagte \n\n \n\nsowie \n\n \n\nB._____, \n\nPrivatklägerin, Berufungsbeklagte und Anschlussberufungsklägerin \n\n \n\nunentgeltlich vertreten durch Rechtsanwalt lic. iur. et dipl. Ing. HTL Y._____ \n\n \n\nbetreffend Vergewaltigung etc. und Widerruf \n\n \nBerufung gegen ein Urteil des Bezirksgerichtes Dietikon vom 11. Oktober \n\n2016 (DG150047) \n\n\n\n- 2 - \n\n__________________________ \n\n \nAnklage: \n\nDie Anklageschrift der Staatsanwaltschaft IV des Kantons Zürich vom 4. Dezem-\n\nber 2015 (Urk. 37) und die Nachtragsanklage vom 26. Februar 2016 (Urk. 22) \n\nsind diesem Urteil beigeheftet. \n\nBeschluss und Urteil der Vorinstanz: \n\n"Es wird beschlossen: \n\n1. Prozess Nr. DG160008-M wird mit dem vorliegenden Prozess \n\nNr. DG150047-M vereinigt und unter der letztgenannten Prozess-Nummer \n\nweitergeführt. \n\n2. Prozess Nr. DG160008-M wird als dadurch erledigt abgeschrieben. \n\n3. Mündliche Eröffnung, Begründung und schriftliche Mitteilung im Dispositiv \n\nsowie in vollständiger Ausfertigung mit nachfolgendem Erkenntnis. \n\n\n\n- 3 - \n\nEs wird erkannt: \n\n1. Der Beschuldigte ist schuldig \n\n− der Vergewaltigung im Sinne von Art. 190 Abs. 1 StGB; \n\n− der mehrfachen Nötigung im Sinne von Art. 181, teilweise des Ver-\n\nsuchs dazu im Sinne von Art. 181 in Verbindung mit Art. 22 Abs. 1 \n\nStGB; \n\n− der Drohung im Sinne von Art. 180 Abs. 1 StGB in Verbindung mit \n\nArt. 180 Abs. 2 lit. a StGB; \n\n− des Missbrauchs einer Fernmeldeanlage im Sinne von Art. 179septies \n\nStGB; \n\n− des Ungehorsams gegen amtliche Verfügungen im Sinne von Art. 292 \n\nStGB. \n\n2. Der Beschuldigte wird bestraft mit 44 Monaten Freiheitsstrafe (wovon bis \n\nund mit heute 416 Tage durch Haft sowie durch vorzeitigen Strafvollzug er-\n\nstanden sind) sowie mit einer Busse von Fr. 1\'000.–. \n\n3. Die Freiheitsstrafe wird vollzogen, die Busse ist zu bezahlen. \n\n4. Bezahlt der Beschuldigte die Busse schuldhaft nicht, so tritt an deren Stelle \n\neine Ersatzfreiheitsstrafe von 10 Tagen. \n\n5. Der mit Urteil des Bezirksgerichts Dietikon vom 11. März 2015 für eine Geld-\n\nstrafe von 60 Tagessätzen zu Fr. 30.– (wovon 8 Tagessätze als durch Un-\n\ntersuchungshaft geleistet gelten) unter Ansetzung einer Probezeit von 2 Jah-\n\nren gewährte bedingte Straffvollzug wird widerrufen; der Vollzug der Geld-\n\nstrafe wird angeordnet. \n\n6. Dem Beschuldigten wird im Sinne von Art. 67b Abs. 2 lit. a StGB untersagt, \n\nmit der Privatklägerin B._____ in irgendeiner Weise (persönlich, telefonisch, \n\n\n\n- 4 - \n\nschriftlich, SMS, Mail etc.) direkt oder über Drittpersonen Kontakt aufzuneh-\n\nmen. Das Kontaktverbot gilt für die Dauer von 3 Jahren. \n\n7. Dem Beschuldigten wird im Sinne von Art. 67b Abs. 2 lit. b und c StGB un-\n\ntersagt, sich der Privatklägerin B._____ zu nähern oder sich in einem Um-\n\nkreis von 100 Metern ihres jeweiligen Wohnortes (derzeit: … [Adresse]) auf-\n\nzuhalten. Das Rayonverbot gilt für die Dauer von 3 Jahren. \n\n8. Für die Dauer des Kontakt- und Rayonverbots gemäss Ziffer 6 und 7 wird \n\neine Bewährungshilfe im Sinne von Art. 67b Abs. 4 StGB angeordnet. \n\n9. Der Beschuldigte wird verpflichtet, der Privatklägerin B._____ Fr. 15\'000.– \n\nzuzüglich 5 % Zins ab 5. April 201 ...
#  'metadata': {'Author': 'lic.iur. B. Stiefel',
#   'Category': '$Arc$',
#   'Comments': '',
#   'Company': 'Obergericht des Kantons Zürich',
#   'Content-Type': 'application/pdf',
#   'Creation-Date': '2018-07-12T07:46:47Z',
#   'Keywords': '',
#   'Last-Modified': '2018-07-12T07:46:51Z',
#   'Last-Save-Date': '2018-07-12T07:46:51Z',
#   'Manager': 'Bruno Rickenbach',
#   'SourceModified': 'D:20180712074644',
#   'X-Parsed-By': ['org.apache.tika.parser.DefaultParser',
#    'org.apache.tika.parser.pdf.PDFParser'],
#   'X-TIKA:parse_time_millis': '1053',
#   'access_permission:assemble_document': 'true',
#   'access_permission:can_modify': 'true',
#   'access_permission:can_print': 'true',
#   'access_permission:can_print_degraded': 'true',
#   'access_permission:extract_content': 'true',
#   'access_permission:extract_for_accessibility': 'true',
#   'access_permission:fill_in_form': 'true',
#   'access_permission:modify_annotations': 'true',
#   'cp:subject': 'U2001',
#   'created': '2018-07-12T07:46:47Z',
#   'creator': 'lic.iur. B. Stiefel',
#   'date': '2018-07-12T07:46:51Z',
#   'dc:creator': 'lic.iur. B. Stiefel',
#   'dc:description': 'U2001',
#   'dc:format': 'application/pdf; version=1.5',
#   'dc:language': 'DE-CH',
#   'dc:subject': '',
#   'dc:title': 'Dispositiv allgemein SB',
#   'dcterms:created': '2018-07-12T07:46:47Z',
#   'dcterms:modified': '2018-07-12T07:46:51Z',
#   'description': 'U2001',
#   'language': 'DE-CH',
#   'meta:author': 'lic.iur. B. Stiefel',
#   'meta:creation-date': '2018-07-12T07:46:47Z',
#   'meta:keyword': '',
#   'meta:save-date': '2018-07-12T07:46:51Z',
#   'modified': '2018-07-12T07:46:51Z',
#   'pdf:PDFVersion': '1.5',
#   'pdf:docinfo:created': '2018-07-12T07:46:47Z',
#   'pdf:docinfo:creator': 'lic.iur. B. Stiefel',
#   'pdf:docinfo:creator_tool': 'Acrobat PDFMaker 11 for Word',
#   'pdf:docinfo:custom:Category': '$Arc$',
#   'pdf:docinfo:custom:Comments': '',
#   'pdf:docinfo:custom:Company': 'Obergericht des Kantons Zürich',
#   'pdf:docinfo:custom:Manager': 'Bruno Rickenbach',
#   'pdf:docinfo:custom:SourceModified': 'D:20180712074644',
#   'pdf:docinfo:keywords': '',
#   'pdf:docinfo:modified': '2018-07-12T07:46:51Z',
#   'pdf:docinfo:producer': 'Adobe LiveCycle PDF Generator',
#   'pdf:docinfo:subject': 'U2001',
#   'pdf:docinfo:title': 'Dispositiv allgemein SB',
#   'pdf:encrypted': 'false',
#   'producer': 'Adobe LiveCycle PDF Generator',
#   'resourceName': 'SB170139-O1.pdf',
#   'subject': 'U2001',
#   'title': 'Dispositiv allgemein SB',
#   'xmp:CreatorTool': 'Acrobat PDFMaker 11 for Word',
#   'xmpMM:DocumentID': 'uuid:28c17c25-83b9-49fb-9492-d6626f9a0bc2',
#   'xmpTPg:NPages': '38'}}

# %%
# def read_pdf(filename):
#    text = parser.from_file(filename)
#    return(text)
#    all_files = glob.glob(\".\\\\pdf_Obergericht\\\\PA140034-O1.pdf\")
#    pdf_text_list=[]
    
# for i,file in enumerate(all_files):
#    text=read_pdf(file)
#    pdf_text_list.append(text['content'])

# %%
import re

# %%
re.findall(r"Es wird erkannt:(\)",str(parsedPDF['content']))
# Out:
# []

# %%
len(parsedPDF['content'])
# Out:
# 86647

# %%
import pandas as pd

# %%
# pdf: es wird erkannt

start_char1 = parsedPDF['content'].find("Es wird erkannt:")
start_char1

new_text = parsedPDF['content'][start_char1:]
new_text
stuff = new_text[ending:].strip()
stuff = stuff[stuff.find("5."):]
stuff
# dict["punishment"] = 
# stuff[0:stuff.find("Gerichtskasse")]
# stuff
# Out:
# '5. Bezüglich des Beginns des Kontakt- und Rayonverbots legt Art. 67c \n\nAbs. 1 StGB fest, dass das Verbot am Tag wirksam wird, an dem das Urteil \n\nrechtskräftig wird. Dem Antrag der Privatklägerin den Beginn des Verbots auf den \n\nZeitpunkt der Entlassung des Beschuldigten aus dem Strafvollzug festzusetzen, \n\nkann daher nicht entsprochen werden. Im Übrigen wäre die Privatklägerin dies-\n\nfalls während der Dauer des Freiheitsentzuges des Beschuldigten allfälligen von \n\ndiesem veranlassten Kontaktaufnahmen durch Dritte schutzlos ausgesetzt. So-\n\nweit die Privatklägerin befürchtet, das dreijährige Verbot würde noch während des \n\nFreiheitsentzugs des Beschuldigten ablaufen und somit nach seiner Entlassung \n\n\n\n- 33 - \n\nnicht mehr gelten (Urk. 94 S. 2), ist sie auf Art. 67c Abs. 2 StGB hinzuweisen, wo-\n\nnach die Dauer des Vollzugs einer Freiheitsstrafe oder einer freiheitsentziehen-\n\nden Massnahme nicht auf die Dauer des Verbots anzurechnen ist.  \n\nVIII. Zivilansprüche \n\n 1. Die Privatklägerin hat sich mit Eingabe ihrer unentgeltlichen Rechtsvertre-\n\ntung vom 14. Mai 2015 ordnungsgemäss konstituiert (Art. 118 StPO; Urk. 22/1) \n\nund beantragt mit ihrer Anschlussberufung eine Erhöhung der vorinstanzlich fest-\n\ngesetzten Genugtuungssumme von Fr. 15\'000.– (Urk. 87 S. 47 ff., 54) auf min-\n\ndestens die bereits vor Vorinstanz verlangten Fr. 35\'000.–, zuzüglich Zins zu 5 % \n\nab dem 5. April 2015 (Urk. 69 S. 3; Urk. 94). An der Berufungsverhandlung redu-\n\nzierte die Privatklägerin ihr Genugtuungsbegehren auf Fr. 20\'000.– (Urk. 103 S. 1, \n\nProt. II S. 7 f.). \n\n 2. Die allgemeinen Voraussetzungen und Grundlagen für die Beurteilung der \n\nGenugtuungsansprüche bei einer Vergewaltigung nach Art. 49 OR wurden durch \n\ndie Vorinstanz zutreffend wiedergegeben (Urk. 87 S. 48 f.). Dies braucht nicht \n\nwiederholt zu werden. \n\n 3. Mit seiner Tat hat der Beschuldigte widerrechtlich und schuldhaft in die \n\npsychische, physische und sexuelle Integrität der Privatklägerin eingegriffen und \n\nsie dadurch in ihren Persönlichkeitsrechten verletzt. Die notwendige Schwere der \n\nVerletzung ist in objektiver Hinsicht ohne Weiteres gegeben. Die der Privatkläge-\n\nrin zugefügte seelische Unbill kann nicht auf andere Weise als durch die Entrich-\n\ntung einer Geldsumme abgegolten werden. \n\n 3.1. Laut Arztbericht vom 19. September 2016 und den Austrittsberichten \n\nder Psychiatrischen Universitätsklinik Zürich vom 15. Oktober 2015 und 23. Mai \n\n2016 litt die Privatklägerin an einer schweren depressiven Episode ohne psycho-\n\ntische Symptome, vor dem Hintergrund aktueller Gewalterfahrung (Urk. 70/1 f.; \n\nUrk. 70/4). Dem Arztbericht vom 19. September 2016 ist aber ebenso zu entneh-\n\nmen, dass sie bereits seit 1982 unter depressiven Episoden litt. Die Beschwerden \n\nwürden aus Sicht der Privatklägerin auch mit den gewaltvollen Beziehungen in ih-\n\n\n\n- 34 - \n\nrer Vergangenheit zusammenhängen, insbesondere den Gewalttätigkeiten ihrer \n\nMutter und ihres ersten Ehemannes (Urk. 70/1). Seit der Vergewaltigung hätten \n\nim Rahmen der depressiven Symptomatik insbesondere starke Schlafstörungen \n\nsowie Ängste, die Wohnung zu verlassen, im Vordergrund gestanden. Als der Be-\n\nschuldigte (zwischenzeitlich) aus der Untersuchungshaft entlassen worden war, \n\nsei es bei der Privatklägerin zu einer suizidalen Krise gekommen, welche eine \n\nfürsorgerische Unterbringung erfordert habe. Bei ihr liege eine schwere Traumati-\n\nsierung vor, welche die Diagnosekriterien einer posttraumatischen Belastungsstö-\n\nrung jedoch nicht erfüllen würden (Urk. 70/4). \n\n 3.2. Gestützt auf die vorhandenen Arztbefunde kam die Vorinstanz zu Recht \n\nzum Schluss, dass mit diesen nicht rechtsgenügend erstellt ist, dass sämtliche \n\nBeschwerden der Privatklägerin ausschliesslich auf die erlittene Vergewaltigung \n\nzurückzuführen sind, zumal sie bereits über vorbestehende langjährige psychi-\n\nsche Leiden verfügte. Unter  ...

# %%
chars = len("Das Gericht erkennt:")
start_char = parsedPDF['content'].find("Das Gericht erkennt:")
new_text = parsedPDF['content'][start_char:]
new_text 
#second = new_text[chars:].find("Das Gericht erkennt:")
#text2 = new_text[second:]
#third = text2.find("Das Gericht erkennt:")
#text3 = text2[third:]
# Out:
# '\n'

# %%
len(text2)
# Out:
# 1

# %%
len(text3)
# Out:
# 1

# %%
char_nums = []
for i in re.finditer("Das Gericht erkennt:",new_text):
    char_nums.append(i.end())

# %%
char_nums
# Out:
# []

# %%
ending = max(char_nums)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-3928c92d319c> in <module>
# ----> 1 ending = max(char_nums)
#
# ValueError: max() arg is an empty sequence

# %%
stuff = new_text[ending:].strip()
stuff = stuff[stuff.find("wird bestraft"):]
# dict["punishment"] = 
stuff[0:stuff.find("Gerichtskasse")]
# Out:
# ''

# %%
stuff
# Out:
# ''

# %% [markdown]
# ## Make the Loop

# %%
import glob
import os
import pandas as pd
from tika import parser

# %%
dicts = {}

#  = glob.glob(\".\\\\pdf_Obergericht\\\\*.pdf\")

# path = '/Users/Dominik Balmer/Documents/LEDE_2019/data-studio-projects/pdf_Obergericht/*.pdf'
# files = glob.glob(path) 


all_files = glob.glob('./pdf_Obergericht/*.pdf')

for file in all_files:
    text = parser.from(file)


def read_pdf(filename):
    text = parser.from_file(filename)
    return(text)
    files = glob.glob('./pdf_Obergericht/*.pdf')
    # pdf_text_list=[]
    
    
for i,file in enumerate(files):
    
    text=read_pdf(file)
    # pdf_text_list.append(text['content'])
    
    dicts["year"] = parsedPDF['metadata']['date']
    dicts["author"] = parsedPDF['metadata']['creator']
    dicts["title"] = parsedPDF['metadata']['title']
    x = parsedPDF['content'].find("Es wird erkannt:")
    y = parsedPDF['content'][x:]

    dicts["judgement"] = y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4ffa75753ea0> in <module>
#      13
#      14
# ---> 15 for i,file in enumerate(files):
#      16     text=read_pdf(file)
#      17     # pdf_text_list.append(text['content'])
#
# NameError: name 'files' is not defined

# %%
import os
pdf_list = os.listdir("pdf_Obergericht")
pdf_list
n = 4
del pdf_list[:n]
pdf_list
# Out:
# ['SB100517-O1.pdf',
#  'SB100743-O1.pdf',
#  'SB110096-O1.pdf',
#  'SB110279-O1.pdf',
#  'SB110303-O1.pdf',
#  'SB110314-O1.pdf',
#  'SB110316-O1.pdf',
#  'SB110327-O1.pdf',
#  'SB110353-O1.pdf',
#  'SB110363-O1.pdf',
#  'SB110381-O1.pdf',
#  'SB110414-O1.pdf',
#  'SB110435-O1.pdf',
#  'SB110438-O1.pdf',
#  'SB110455-O1.pdf',
#  'SB110481-O1.pdf',
#  'SB110482-O1.pdf',
#  'SB110506-O1.pdf',
#  'SB110509-O1.pdf',
#  'SB110514-O1.pdf',
#  'SB110517-O1.pdf',
#  'SB110539-O1.pdf',
#  'SB110582-O1.pdf',
#  'SB110588-O1.pdf',
#  'SB110601-O1.pdf',
#  'SB110625-O1.pdf',
#  'SB110668-O1.pdf',
#  'SB110706-O1.pdf',
#  'SB120026-O1.pdf',
#  'SB120048-O1.pdf',
#  'SB120084-O1.pdf',
#  'SB120092-O1.pdf',
#  'SB120095-O1.pdf',
#  'SB120148-O1.pdf',
#  'SB120200-O1.pdf',
#  'SB120212-O1.pdf',
#  'SB120233-O1.pdf',
#  'SB120254-O1.pdf',
#  'SB120264-O1.pdf',
#  'SB120302-O1.pdf',
#  'SB120308-O1.pdf',
#  'SB120319-O1.pdf',
#  'SB120323-O1.pdf',
#  'SB120330-O1.pdf',
#  'SB120345-O1.pdf',
#  'SB120454-O1.pdf',
#  'SB120476-O1.pdf',
#  'SB120486-O1.pdf',
#  'SB120504-O1.pdf',
#  'SB120525-O1.pdf',
#  'SB120527-O1.pdf',
#  'SB130009-O1.pdf',
#  'SB130026-O1.pdf',
#  'SB130079-O1.pdf',
#  'SB130134-O1.pdf',
#  'SB130168-O1.pdf',
#  'SB130187-O1.pdf',
#  'SB130220-O1.pdf',
#  'SB130248-O1.pdf',
#  'SB130277-O1.pdf',
#  'SB130306-O1.pdf',
#  'SB130367-O1.pdf',
#  'SB130430-O1.pdf',
#  'SB130450-O1.pdf',
#  'SB130460-O1.pdf',
#  'SB130479-O1.pdf',
#  'SB130485-O1.pdf',
#  'SB130491-O1.pdf',
#  'SB140035-O1.pdf',
#  'SB140051-O1.pdf',
#  'SB140080-O1.pdf',
#  'SB140099-O1.pdf',
#  'SB140149-O1.pdf',
#  'SB140194-O1.pdf',
#  'SB140196-O1.pdf',
#  'SB140207-O1.pdf',
#  'SB140230-O1.pdf',
#  'SB140357-O1.pdf',
#  'SB140387-O1.pdf',
#  'SB140425-O1.pdf',
#  'SB140458-O1.pdf',
#  'SB140514-O1.pdf',
#  'SB150004-O1.pdf',
#  'SB150034-O1.pdf',
#  'SB150061-O1.pdf',
#  'SB150091-O1.pdf',
#  'SB150197-O1.pdf',
#  'SB150250-O1.pdf',
#  'SB150286-O1.pdf',
#  'SB150350-O1.pdf',
#  'SB150361-O1.pdf',
#  'SB150387-O1.pdf',
#  'SB150393-O1.pdf',
#  'SB150418-O1.pdf',
#  'SB150427-O1.pdf',
#  'SB150531-O1.pdf',
#  'SB160085-O1.pdf',
#  'SB160091-O1.pdf',
#  'SB160113-O1.pdf',
#  'SB160158-O1.pdf',
#  'SB160171-O1.pdf',
#  'SB160174-O1.pdf',
#  'SB160196-O1.pdf',
#  'SB160205-O1.pdf',
#  'SB160209-O1.pdf',
#  'SB160250-O1.pdf',
#  'SB160275-O1.pdf',
#  'SB160288-O1.pdf',
#  'SB160301-O1.pdf',
#  'SB160339-O1.pdf',
#  'SB160346-O1.pdf',
#  'SB160355-O1.pdf',
#  'SB160446-O1.pdf',
#  'SB160467-O1.pdf',
#  'SB160484-O1.pdf',
#  'SB170007-O1.pdf',
#  'SB170093-O1.pdf',
#  'SB170139-O1.pdf',
#  'SB170190-O1.pdf',
#  'SB170194-O1.pdf',
#  'SB170226-O1.pdf',
#  'SB170301-O1.pdf',
#  'SB170374-O1.pdf',
#  'SB170394-O1.pdf',
#  'SB170446-O1.pdf',
#  'SB170460-O1.pdf',
#  'SB180020-O1.pdf',
#  'SB180195-O1.pdf']

# %%
new_list = []

for var in pdf_list:
    parsedPDF=parser.from_file(f'C:/Users/Dominik Balmer/Documents/LEDE_2019/data-studio-projects/pdf_Obergericht/{var}')
    dicts = {}

    dicts["year"] = parsedPDF['metadata']['date']
    dicts["author"] = parsedPDF['metadata']['creator']
    try: 
        dicts["title"] = parsedPDF['metadata']['title']
    except:
        pass
    try:
        x = parsedPDF['content'].find("Es wird beschlossen:")
    except: 
        pass
    try:
        y = parsedPDF['content'][x:]
    except: 
        pass
    try:
        a = parsedPDF['content'].find("Es wird erkannt:")
    except: 
        pass
    try:
        b = parsedPDF['content'][a:]
    except: 
        pass
    try:
        c = parsedPDF['content'].find("Das Gericht erkennt:")
    except: 
        pass
    try:
        d = parsedPDF['content'][c:]
    except: 
        pass
    try:
        dicts["judgement2"] = d
    except: 
        pass
    try:
        dicts["judgement1"] = b
    except: 
        pass
    try:
        dicts["judgement"] = y
    except: 
        pass
    new_list.append(dicts)

df = pd.DataFrame(new_list)
df.head()
# Out:
#                   author                                          judgement  \
# 0         Dr.D. Bussmann                                                 \n
# 1  lic.iur. L. Chitvanni                                                 \n
# 2    lic.iur. S. Janssen  Es wird beschlossen: \n\n1. Es wird festgestel...
# 3           Dr. Bischoff                                                 \n
# 4     lic. iur. N. Burri  Es wird beschlossen: \n\n1. Auf die Berufung d...
#
#                                           judgement1  \
# 0                                                 \n
# 1                                                 \n
# 2  Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                 \n
# 4  Es wird erkannt: \n \n\n1. Der Beschuldigte is...
#
#                                           judgement2  \
# 0  Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 1  Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 2                                                 \n
# 3  Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4  Das Gericht erkennt: \n\n1. Der Angeklagte C._...
#
#                                      title                  year
# 0  Antragsformular/Dispositiv allgemein SB  2014-10-29T20:42:39Z
# 1            Antragsformular Freispruch SB  2014-10-30T20:43:52Z
# 2  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z
# 3                  Dispositiv allgemein SB  2014-10-30T20:45:26Z
# 4  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z

# %%
df.to_csv('judgements_all.csv')

# %%
#this works 

parsedPDF=parser.from_file('C:/Users/Dominik Balmer/Documents/LEDE_2019/data-studio-projects/pdf_Obergericht/SB170139-O1.pdf')
#parsedPDF['content'][11]
parsedPDF['metadata']['title']
parsedPDF['metadata']['date']
parsedPDF['metadata']['creator']
# Out:
# 'lic.iur. B. Stiefel'

# %%
df['guilty'] = df.judgement2.str.contains('nicht schuldig')
df.head()
# Out:
#                   author                                          judgement  \
# 0         Dr.D. Bussmann                                                 \n
# 1  lic.iur. L. Chitvanni                                                 \n
# 2    lic.iur. S. Janssen  Es wird beschlossen: \n\n1. Es wird festgestel...
# 3           Dr. Bischoff                                                 \n
# 4     lic. iur. N. Burri  Es wird beschlossen: \n\n1. Auf die Berufung d...
#
#                                           judgement1  \
# 0                                                 \n
# 1                                                 \n
# 2  Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                 \n
# 4  Es wird erkannt: \n \n\n1. Der Beschuldigte is...
#
#                                           judgement2  \
# 0  Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 1  Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 2                                                 \n
# 3  Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4  Das Gericht erkennt: \n\n1. Der Angeklagte C._...
#
#                                      title                  year  guilty
# 0  Antragsformular/Dispositiv allgemein SB  2014-10-29T20:42:39Z    True
# 1            Antragsformular Freispruch SB  2014-10-30T20:43:52Z    True
# 2  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                  Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False

# %%
df_new = df[(df['guilty']==False)]
df_new
# Out:
#                                       author  \
# 2                        lic.iur. S. Janssen
# 3                               Dr. Bischoff
# 4                         lic. iur. N. Burri
# 6                       lic.iur. C. Semadeni
# 8                                  T. Müller
# 9                      lic. iur. T. Walthert
# 10    Lichtensteiger Beat Obergericht Zürich
# 12                             Maya Bertschi
# 13                         lic. iur. R. Naef
# 15                   lic.iur. E. Leuenberger
# 16                                 T. Müller
# 17   Brühwiler Daniela Bezirksgericht Zürich
# 18                        lic.iur. C. Laufer
# 19                   lic.iur. E. Leuenberger
# 20                   lic.iur. E. Leuenberger
# 21                   lic.iur. E. Leuenberger
# 22                   lic. iur. Haike Aardoom
# 23                           Claudia Grieder
# 24                   lic.iur. E. Leuenberger
# 25                       lic.iur. B. Stiefel
# 26                       R. Affolter-Fischer
# 27                        lic. iur. J. Stark
# 28                    lic. iur. M. Langmeier
# 29                               B. Bosshard
# 30                 Dr. iur. Patrick Bischoff
# 31                       lic. iur. S. Oswald
# 32                         lic.iur. C. Brenn
# 33                             Maya Bertschi
# 34                            Dr. S. Janssen
# 35                        lic.iur. A. Hafner
# ..                                       ...
# 98                                  P. Ernst
# 99                                  P. Ernst
# 100                           S. Kümin Grell
# 101                     lic. iur. Ch. Spiess
# 102                       lic.iur. A. Hafner
# 103                              C. von Moos
# 104                       S. Gorisek-Lentini
# 105       lic.iur. S. Hürlimann Winterhalter
# 106                                S. Neukom
# 107                              B. Bosshard
# 108                               S. Bärtsch
# 109                lic.iur. B. Wasser-Keller
# 110                          lic.iur. B. Gut
# 111                              C. von Moos
# 112                              B. Bosshard
# 113                       S. Gorisek-Lentini
# 114                               S. Bärtsch
# 115                          Claudia Grieder
# 116                    lic.iur. L. Chitvanni
# 117                      lic.iur. B. Stiefel
# 118                              B. Bosshard
# 119                               B. Schärer
# 120                               B. Schärer
# 121                     lic. iur. St. Volken
# 122                              B. Bosshard
# 123                      lic.iur. B. Stiefel
# 124                                S. Maurer
# 125                          lic.iur. B. Gut
# 126                       S. Gorisek-Lentini
# 127                        lic.iur. C. Brenn
#
#                                              judgement  \
# 2    Es wird beschlossen: \n\n1. Es wird festgestel...
# 3                                                   \n
# 4    Es wird beschlossen: \n\n1. Auf die Berufung d...
# 6                                                   \n
# 8    Es wird beschlossen: \n\n1. Es wird festgestel...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird beschlossen: \n\n1. Es wird festgestel...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18                                                  \n
# 19                                                  \n
# 20                                                  \n
# 21   Es wird beschlossen: \n\n1. Es wird festgestel...
# 22                                                  \n
# 23   Es wird beschlossen: \n\n1. Es wird festgestel...
# 24   Es wird beschlossen: \n\n1. Auf die Anklage be...
# 25   Es wird beschlossen: \n\n1. Auf die selbständi...
# 26   Es wird beschlossen: \n\n1. Es wird festgestel...
# 27                                                  \n
# 28   Es wird beschlossen: \n\n1. Es wird festgestel...
# 29   Es wird beschlossen: \n\n1. Es wird festgestel...
# 30                                                  \n
# 31   Es wird beschlossen: \n\n1. Es wird festgestel...
# 32                                                  \n
# 33                                                  \n
# 34   Es wird beschlossen: \n\n1. Es wird festgestel...
# 35   Es wird beschlossen: \n\n1. Es wird festgestel...
# ..                                                 ...
# 98   Es wird beschlossen: \n\n1. Es wird festgestel...
# 99   Es wird beschlossen: \n\n1. Es wird festgestel...
# 100                                                 \n
# 101  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 102  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 103  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 104  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 105  Es wird beschlossen: \n\n1. Das Gesuch des Bes...
# 106                                                 \n
# 107  Es wird beschlossen: \n\n1. Auf die Anklage be...
# 108  Es wird beschlossen: \n\n1. Es wird festgestel...
# 109  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 110  Es wird beschlossen: \n\n1. In Bezug auf die v...
# 111  Es wird beschlossen: \n\n1. Es wird festgestel...
# 112  Es wird beschlossen: \n\n1. Es wird festgestel...
# 113  Es wird beschlossen: \n\n1. Es wird festgestel...
# 114  Es wird beschlossen: \n\n1. Es wird festgestel...
# 115  Es wird beschlossen: \n\n1. Es wird festgestel...
# 116  Es wird beschlossen:  \n\n1. Es wird festgeste...
# 117  Es wird beschlossen: \n\n1. Prozess Nr. DG1600...
# 118  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 119  Es wird beschlossen: \n\n1. Es wird festgestel...
# 120  Es wird beschlossen: \n\n1. Es wird festgestel...
# 121  Es wird beschlossen: \n\n1. Es wird festgestel...
# 122  Es wird beschlossen: \n\n1. Es wird festgestel...
# 123                                                 \n
# 124  Es wird beschlossen: \n\n1. Es wird festgestel...
# 125                                                 \n
# 126  Es wird beschlossen: \n\n1. Es wird festgestel...
# 127  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                             judgement1  \
# 2    Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                   \n
# 4    Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 6                                                   \n
# 8    Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird erkannt: \n\n1. Der Angeklagte B._____...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18   Es wird erkannt: \n\n1. Der Beschuldigte ist d...
# 19                                                  \n
# 20                                                  \n
# 21   Es wird erkannt:  \n\n1. Der Beschuldigte A.__...
# 22   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 23   Es wird erkannt: \n\n1. Es wird eine stationär...
# 24   Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 25   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 26   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 27                                                  \n
# 28   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 29   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 30                                                  \n
# 31   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 32   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 33   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 34   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 35   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# ..                                                 ...
# 98   Es wird erkannt: \n\n1. Der Beschuldigte ist f...
# 99   Es wird erkannt: \n\n1. a) Der Beschuldigte A....
# 100  Es wird erkannt: \n\n1. Die Beschuldigte ist s...
# 101  Es wird erkannt: \n\n1. Es wird festgestellt, ...
# 102  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 103  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 104  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 105  Es wird erkannt: \n\n1. Bezüglich der Anklagev...
# 106  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 107  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 108  Es wird erkannt: \n\n1.  Das Verfahren gegen d...
# 109  Es wird erkannt: \n\n1. Der Beschuldigte F.___...
# 110  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 111  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 112  Es wird erkannt: \n\n1. Der beschuldigte Jugen...
# 113  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 114  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 115  Es wird erkannt: \n\n1. Dem Beschuldigten wird...
# 116  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 117  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 118  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 119  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 120  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 121  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 122  Es wird erkannt: \n\n1. Der Beschuldigte E.___...
# 123  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 124  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 125  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 126  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 127  Es wird erkannt: \n\n1. Der Beschuldigte ist d...
#
#                                             judgement2  \
# 2                                                   \n
# 3    Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4    Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 6    Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 8    Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 9    Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 10   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 12   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 13   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 15   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 16   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 17   Das Gericht erkennt: \n\n1. Der Angeklagte wir...
# 18                                                  \n
# 19   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 20   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 21                                                  \n
# 22                                                  \n
# 23   Das Gericht erkennt: \n\n1. Es wird festgestel...
# 24   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 25                                                  \n
# 26                                                  \n
# 27                                                  \n
# 28   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 29                                                  \n
# 30   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 31                                                  \n
# 32                                                  \n
# 33   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 34                                                  \n
# 35                                                  \n
# ..                                                 ...
# 98                                                  \n
# 99                                                  \n
# 100                                                 \n
# 101                                                 \n
# 102                                                 \n
# 103                                                 \n
# 104                                                 \n
# 105                                                 \n
# 106                                                 \n
# 107                                                 \n
# 108                                                 \n
# 109                                                 \n
# 110                                                 \n
# 111                                                 \n
# 112                                                 \n
# 113                                                 \n
# 114                                                 \n
# 115  Das Gericht erkennt: \n\n1. Der Beschuldigte B...
# 116                                                 \n
# 117                                                 \n
# 118                                                 \n
# 119                                                 \n
# 120                                                 \n
# 121                                                 \n
# 122                                                 \n
# 123                                                 \n
# 124                                                 \n
# 125                                                 \n
# 126                                                 \n
# 127                                                 \n
#
#                                        title                  year  guilty
# 2    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                    Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 6    Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 8                    Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
# 9                    Dispositiv allgemein SB  2014-10-30T20:46:58Z   False
# 10                                       NaN  2014-10-29T19:22:10Z   False
# 12             Antragsformular Freispruch SB  2014-10-29T18:08:51Z   False
# 13                   Dispositiv allgemein SB  2014-10-30T20:47:32Z   False
# 15   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:42:39Z   False
# 16         Antrag Schuldspruch (ausführlich)  2014-10-29T20:11:04Z   False
# 17   Antragsformular/Dispositiv allgemein SE  2014-10-29T18:00:11Z   False
# 18                   Dispositiv allgemein SB  2014-10-29T18:16:21Z   False
# 19   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:51Z   False
# 20   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:12:52Z   False
# 21                       Antrag Schuldspruch  2014-10-29T18:40:36Z   False
# 22                       Antrag Schuldspruch  2014-10-29T19:59:27Z   False
# 23                         Antrag Freispruch  2014-10-29T18:28:07Z   False
# 24   Antragsformular/Dispositiv allgemein SB  2014-10-29T20:17:20Z   False
# 25                   Dispositiv allgemein SB  2014-10-30T18:25:47Z   False
# 26                       Antrag Schuldspruch  2014-10-29T21:03:30Z   False
# 27                         Antrag Freispruch  2014-10-29T19:02:46Z   False
# 28         Antrag Schuldspruch (ausführlich)  2014-10-29T19:27:24Z   False
# 29                   Dispositiv allgemein SB  2014-10-29T19:15:51Z   False
# 30             Urteilsdispositiv SB (normal)  2014-10-29T18:42:38Z   False
# 31                   Dispositiv allgemein SB  2014-10-29T20:19:08Z   False
# 32                       Antrag Schuldspruch  2014-10-29T19:28:57Z   False
# 33   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:47Z   False
# 34                       Antrag Schuldspruch  2014-10-29T20:55:39Z   False
# 35                       Antrag Schuldspruch  2014-10-29T20:14:25Z   False
# ..                                       ...                   ...     ...
# 98                       Antrag Schuldspruch  2016-12-23T07:31:22Z   False
# 99                       Antrag Schuldspruch  2018-11-14T10:31:11Z   False
# 100                      Antrag Schuldspruch  2017-12-06T07:47:37Z   False
# 101                  Dispositiv allgemein SB  2016-11-30T07:39:42Z   False
# 102                        Antrag Freispruch  2017-06-07T04:45:50Z   False
# 103                      Antrag Schuldspruch  2018-12-12T07:10:06Z   False
# 104                  Dispositiv allgemein SB  2018-03-07T08:59:31Z   False
# 105        Antrag Schuldspruch (ausführlich)  2017-03-01T17:47:22Z   False
# 106                      Antrag Schuldspruch  2017-08-23T08:02:23Z   False
# 107                  Dispositiv allgemein SB  2018-04-04T08:53:13Z   False
# 108        Antrag Schuldspruch (ausführlich)  2019-01-02T18:51:01Z   False
# 109                  Dispositiv allgemein SB  2019-05-22T08:28:38Z   False
# 110                      Antrag Schuldspruch  2017-05-10T07:42:51Z   False
# 111                        Antrag Freispruch  2018-01-24T07:45:11Z   False
# 112                  Dispositiv allgemein SB  2018-03-14T08:38:52Z   False
# 113                  Dispositiv allgemein SB  2018-01-17T07:46:20Z   False
# 114        Antrag Schuldspruch (ausführlich)  2018-07-27T07:48:46Z   False
# 115                      Antrag Schuldspruch  2018-05-16T07:08:54Z   False
# 116                      Antrag Schuldspruch  2018-07-18T08:29:53Z   False
# 117                  Dispositiv allgemein SB  2018-07-12T07:46:51Z   False
# 118                  Dispositiv allgemein SB  2018-09-26T08:11:49Z   False
# 119                  Dispositiv allgemein SB  2018-07-05T07:33:01Z   False
# 120                  Dispositiv allgemein SB  2018-09-26T08:10:56Z   False
# 121        Antrag Schuldspruch (ausführlich)  2019-05-02T08:52:41Z   False
# 122                  Dispositiv allgemein SB  2018-06-13T06:52:17Z   False
# 123                  Dispositiv allgemein SB  2019-01-16T08:21:15Z   False
# 124                      Antrag Schuldspruch  2018-08-22T08:06:42Z   False
# 125                        Antrag Freispruch  2019-07-03T08:04:44Z   False
# 126                  Dispositiv allgemein SB  2019-06-19T08:38:16Z   False
# 127                      Antrag Schuldspruch  2019-06-26T06:54:49Z   False
#
# [120 rows x 7 columns]

# %%
df_new['punish'] = df_new.judgement2.str.extract("([^.]*Freiheitsstrafe[^.]*)")
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['punish1'] = df_new.judgement1.str.extract("([^.]*Freiheitsstrafe[^.]*)")
df_new
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                       author  \
# 2                        lic.iur. S. Janssen
# 3                               Dr. Bischoff
# 4                         lic. iur. N. Burri
# 6                       lic.iur. C. Semadeni
# 8                                  T. Müller
# 9                      lic. iur. T. Walthert
# 10    Lichtensteiger Beat Obergericht Zürich
# 12                             Maya Bertschi
# 13                         lic. iur. R. Naef
# 15                   lic.iur. E. Leuenberger
# 16                                 T. Müller
# 17   Brühwiler Daniela Bezirksgericht Zürich
# 18                        lic.iur. C. Laufer
# 19                   lic.iur. E. Leuenberger
# 20                   lic.iur. E. Leuenberger
# 21                   lic.iur. E. Leuenberger
# 22                   lic. iur. Haike Aardoom
# 23                           Claudia Grieder
# 24                   lic.iur. E. Leuenberger
# 25                       lic.iur. B. Stiefel
# 26                       R. Affolter-Fischer
# 27                        lic. iur. J. Stark
# 28                    lic. iur. M. Langmeier
# 29                               B. Bosshard
# 30                 Dr. iur. Patrick Bischoff
# 31                       lic. iur. S. Oswald
# 32                         lic.iur. C. Brenn
# 33                             Maya Bertschi
# 34                            Dr. S. Janssen
# 35                        lic.iur. A. Hafner
# ..                                       ...
# 98                                  P. Ernst
# 99                                  P. Ernst
# 100                           S. Kümin Grell
# 101                     lic. iur. Ch. Spiess
# 102                       lic.iur. A. Hafner
# 103                              C. von Moos
# 104                       S. Gorisek-Lentini
# 105       lic.iur. S. Hürlimann Winterhalter
# 106                                S. Neukom
# 107                              B. Bosshard
# 108                               S. Bärtsch
# 109                lic.iur. B. Wasser-Keller
# 110                          lic.iur. B. Gut
# 111                              C. von Moos
# 112                              B. Bosshard
# 113                       S. Gorisek-Lentini
# 114                               S. Bärtsch
# 115                          Claudia Grieder
# 116                    lic.iur. L. Chitvanni
# 117                      lic.iur. B. Stiefel
# 118                              B. Bosshard
# 119                               B. Schärer
# 120                               B. Schärer
# 121                     lic. iur. St. Volken
# 122                              B. Bosshard
# 123                      lic.iur. B. Stiefel
# 124                                S. Maurer
# 125                          lic.iur. B. Gut
# 126                       S. Gorisek-Lentini
# 127                        lic.iur. C. Brenn
#
#                                              judgement  \
# 2    Es wird beschlossen: \n\n1. Es wird festgestel...
# 3                                                   \n
# 4    Es wird beschlossen: \n\n1. Auf die Berufung d...
# 6                                                   \n
# 8    Es wird beschlossen: \n\n1. Es wird festgestel...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird beschlossen: \n\n1. Es wird festgestel...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18                                                  \n
# 19                                                  \n
# 20                                                  \n
# 21   Es wird beschlossen: \n\n1. Es wird festgestel...
# 22                                                  \n
# 23   Es wird beschlossen: \n\n1. Es wird festgestel...
# 24   Es wird beschlossen: \n\n1. Auf die Anklage be...
# 25   Es wird beschlossen: \n\n1. Auf die selbständi...
# 26   Es wird beschlossen: \n\n1. Es wird festgestel...
# 27                                                  \n
# 28   Es wird beschlossen: \n\n1. Es wird festgestel...
# 29   Es wird beschlossen: \n\n1. Es wird festgestel...
# 30                                                  \n
# 31   Es wird beschlossen: \n\n1. Es wird festgestel...
# 32                                                  \n
# 33                                                  \n
# 34   Es wird beschlossen: \n\n1. Es wird festgestel...
# 35   Es wird beschlossen: \n\n1. Es wird festgestel...
# ..                                                 ...
# 98   Es wird beschlossen: \n\n1. Es wird festgestel...
# 99   Es wird beschlossen: \n\n1. Es wird festgestel...
# 100                                                 \n
# 101  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 102  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 103  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 104  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 105  Es wird beschlossen: \n\n1. Das Gesuch des Bes...
# 106                                                 \n
# 107  Es wird beschlossen: \n\n1. Auf die Anklage be...
# 108  Es wird beschlossen: \n\n1. Es wird festgestel...
# 109  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 110  Es wird beschlossen: \n\n1. In Bezug auf die v...
# 111  Es wird beschlossen: \n\n1. Es wird festgestel...
# 112  Es wird beschlossen: \n\n1. Es wird festgestel...
# 113  Es wird beschlossen: \n\n1. Es wird festgestel...
# 114  Es wird beschlossen: \n\n1. Es wird festgestel...
# 115  Es wird beschlossen: \n\n1. Es wird festgestel...
# 116  Es wird beschlossen:  \n\n1. Es wird festgeste...
# 117  Es wird beschlossen: \n\n1. Prozess Nr. DG1600...
# 118  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 119  Es wird beschlossen: \n\n1. Es wird festgestel...
# 120  Es wird beschlossen: \n\n1. Es wird festgestel...
# 121  Es wird beschlossen: \n\n1. Es wird festgestel...
# 122  Es wird beschlossen: \n\n1. Es wird festgestel...
# 123                                                 \n
# 124  Es wird beschlossen: \n\n1. Es wird festgestel...
# 125                                                 \n
# 126  Es wird beschlossen: \n\n1. Es wird festgestel...
# 127  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                             judgement1  \
# 2    Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                   \n
# 4    Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 6                                                   \n
# 8    Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird erkannt: \n\n1. Der Angeklagte B._____...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18   Es wird erkannt: \n\n1. Der Beschuldigte ist d...
# 19                                                  \n
# 20                                                  \n
# 21   Es wird erkannt:  \n\n1. Der Beschuldigte A.__...
# 22   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 23   Es wird erkannt: \n\n1. Es wird eine stationär...
# 24   Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 25   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 26   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 27                                                  \n
# 28   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 29   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 30                                                  \n
# 31   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 32   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 33   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 34   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 35   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# ..                                                 ...
# 98   Es wird erkannt: \n\n1. Der Beschuldigte ist f...
# 99   Es wird erkannt: \n\n1. a) Der Beschuldigte A....
# 100  Es wird erkannt: \n\n1. Die Beschuldigte ist s...
# 101  Es wird erkannt: \n\n1. Es wird festgestellt, ...
# 102  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 103  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 104  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 105  Es wird erkannt: \n\n1. Bezüglich der Anklagev...
# 106  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 107  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 108  Es wird erkannt: \n\n1.  Das Verfahren gegen d...
# 109  Es wird erkannt: \n\n1. Der Beschuldigte F.___...
# 110  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 111  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 112  Es wird erkannt: \n\n1. Der beschuldigte Jugen...
# 113  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 114  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 115  Es wird erkannt: \n\n1. Dem Beschuldigten wird...
# 116  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 117  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 118  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 119  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 120  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 121  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 122  Es wird erkannt: \n\n1. Der Beschuldigte E.___...
# 123  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 124  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 125  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 126  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 127  Es wird erkannt: \n\n1. Der Beschuldigte ist d...
#
#                                             judgement2  \
# 2                                                   \n
# 3    Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4    Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 6    Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 8    Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 9    Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 10   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 12   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 13   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 15   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 16   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 17   Das Gericht erkennt: \n\n1. Der Angeklagte wir...
# 18                                                  \n
# 19   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 20   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 21                                                  \n
# 22                                                  \n
# 23   Das Gericht erkennt: \n\n1. Es wird festgestel...
# 24   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 25                                                  \n
# 26                                                  \n
# 27                                                  \n
# 28   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 29                                                  \n
# 30   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 31                                                  \n
# 32                                                  \n
# 33   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 34                                                  \n
# 35                                                  \n
# ..                                                 ...
# 98                                                  \n
# 99                                                  \n
# 100                                                 \n
# 101                                                 \n
# 102                                                 \n
# 103                                                 \n
# 104                                                 \n
# 105                                                 \n
# 106                                                 \n
# 107                                                 \n
# 108                                                 \n
# 109                                                 \n
# 110                                                 \n
# 111                                                 \n
# 112                                                 \n
# 113                                                 \n
# 114                                                 \n
# 115  Das Gericht erkennt: \n\n1. Der Beschuldigte B...
# 116                                                 \n
# 117                                                 \n
# 118                                                 \n
# 119                                                 \n
# 120                                                 \n
# 121                                                 \n
# 122                                                 \n
# 123                                                 \n
# 124                                                 \n
# 125                                                 \n
# 126                                                 \n
# 127                                                 \n
#
#                                        title                  year  guilty  \
# 2    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                    Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 6    Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 8                    Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
# 9                    Dispositiv allgemein SB  2014-10-30T20:46:58Z   False
# 10                                       NaN  2014-10-29T19:22:10Z   False
# 12             Antragsformular Freispruch SB  2014-10-29T18:08:51Z   False
# 13                   Dispositiv allgemein SB  2014-10-30T20:47:32Z   False
# 15   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:42:39Z   False
# 16         Antrag Schuldspruch (ausführlich)  2014-10-29T20:11:04Z   False
# 17   Antragsformular/Dispositiv allgemein SE  2014-10-29T18:00:11Z   False
# 18                   Dispositiv allgemein SB  2014-10-29T18:16:21Z   False
# 19   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:51Z   False
# 20   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:12:52Z   False
# 21                       Antrag Schuldspruch  2014-10-29T18:40:36Z   False
# 22                       Antrag Schuldspruch  2014-10-29T19:59:27Z   False
# 23                         Antrag Freispruch  2014-10-29T18:28:07Z   False
# 24   Antragsformular/Dispositiv allgemein SB  2014-10-29T20:17:20Z   False
# 25                   Dispositiv allgemein SB  2014-10-30T18:25:47Z   False
# 26                       Antrag Schuldspruch  2014-10-29T21:03:30Z   False
# 27                         Antrag Freispruch  2014-10-29T19:02:46Z   False
# 28         Antrag Schuldspruch (ausführlich)  2014-10-29T19:27:24Z   False
# 29                   Dispositiv allgemein SB  2014-10-29T19:15:51Z   False
# 30             Urteilsdispositiv SB (normal)  2014-10-29T18:42:38Z   False
# 31                   Dispositiv allgemein SB  2014-10-29T20:19:08Z   False
# 32                       Antrag Schuldspruch  2014-10-29T19:28:57Z   False
# 33   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:47Z   False
# 34                       Antrag Schuldspruch  2014-10-29T20:55:39Z   False
# 35                       Antrag Schuldspruch  2014-10-29T20:14:25Z   False
# ..                                       ...                   ...     ...
# 98                       Antrag Schuldspruch  2016-12-23T07:31:22Z   False
# 99                       Antrag Schuldspruch  2018-11-14T10:31:11Z   False
# 100                      Antrag Schuldspruch  2017-12-06T07:47:37Z   False
# 101                  Dispositiv allgemein SB  2016-11-30T07:39:42Z   False
# 102                        Antrag Freispruch  2017-06-07T04:45:50Z   False
# 103                      Antrag Schuldspruch  2018-12-12T07:10:06Z   False
# 104                  Dispositiv allgemein SB  2018-03-07T08:59:31Z   False
# 105        Antrag Schuldspruch (ausführlich)  2017-03-01T17:47:22Z   False
# 106                      Antrag Schuldspruch  2017-08-23T08:02:23Z   False
# 107                  Dispositiv allgemein SB  2018-04-04T08:53:13Z   False
# 108        Antrag Schuldspruch (ausführlich)  2019-01-02T18:51:01Z   False
# 109                  Dispositiv allgemein SB  2019-05-22T08:28:38Z   False
# 110                      Antrag Schuldspruch  2017-05-10T07:42:51Z   False
# 111                        Antrag Freispruch  2018-01-24T07:45:11Z   False
# 112                  Dispositiv allgemein SB  2018-03-14T08:38:52Z   False
# 113                  Dispositiv allgemein SB  2018-01-17T07:46:20Z   False
# 114        Antrag Schuldspruch (ausführlich)  2018-07-27T07:48:46Z   False
# 115                      Antrag Schuldspruch  2018-05-16T07:08:54Z   False
# 116                      Antrag Schuldspruch  2018-07-18T08:29:53Z   False
# 117                  Dispositiv allgemein SB  2018-07-12T07:46:51Z   False
# 118                  Dispositiv allgemein SB  2018-09-26T08:11:49Z   False
# 119                  Dispositiv allgemein SB  2018-07-05T07:33:01Z   False
# 120                  Dispositiv allgemein SB  2018-09-26T08:10:56Z   False
# 121        Antrag Schuldspruch (ausführlich)  2019-05-02T08:52:41Z   False
# 122                  Dispositiv allgemein SB  2018-06-13T06:52:17Z   False
# 123                  Dispositiv allgemein SB  2019-01-16T08:21:15Z   False
# 124                      Antrag Schuldspruch  2018-08-22T08:06:42Z   False
# 125                        Antrag Freispruch  2019-07-03T08:04:44Z   False
# 126                  Dispositiv allgemein SB  2019-06-19T08:38:16Z   False
# 127                      Antrag Schuldspruch  2019-06-26T06:54:49Z   False
#
#                                                 punish  \
# 2                                                  NaN
# 3                                                  NaN
# 4     Der Angeklagte wird bestraft mit 17 Monaten F...
# 6     Der Angeklagte wird unter Einbezug der widerr...
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...
# 9     Der Angeklagte wird bestraft mit 36 Monaten F...
# 10    Der Angeklagte wird bestraft mit 7 ½ Jahren F...
# 12                                                 NaN
# 13                                                 NaN
# 15    Der Angeklagte wird bestraft mit 28 Monaten F...
# 16    Februar 2006 ausgefällte, bedingte \n\nFreihe...
# 17    März 2009 ausgefällten Freiheitsstrafe rück-\...
# 18                                                 NaN
# 19    Der Angeklagte wird bestraft mit 6 Jahren Fre...
# 20    Der Angeklagte wird bestraft mit 18 Monaten F...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24    Der Angeklagte wird bestraft mit 10 Jahren Fr...
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28    Der Beschuldigte wird unter Einbezug des wide...
# 29                                                 NaN
# 30    Der Beschuldigte wird bestraft mit 4 ½ Jahren...
# 31                                                 NaN
# 32                                                 NaN
# 33    Der Beschuldigte wird bestraft mit 4 Jahren F...
# 34                                                 NaN
# 35                                                 NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                                                punish1
# 2    _____ wird bestraft mit 18 Monaten Freiheitsst...
# 3                                                  NaN
# 4     Der Beschuldigte wird bestraft mit 2 1/2 Jahr...
# 6                                                  NaN
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...
# 9                                                  NaN
# 10                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18    Der Beschuldigte wird bestraft mit 3 ¼ Jahren...
# 19                                                 NaN
# 20                                                 NaN
# 21    Der Beschuldigte wird bestraft mit einer Frei...
# 22    Der Beschuldigte wird bestraft mit 30 Monaten...
# 23                                                 NaN
# 24    Der Angeklagte wird bestraft mit 14 Jahren Fr...
# 25    Der Beschuldigte wird bestraft mit 16 Jahren ...
# 26    Der Beschuldigte wird bestraft mit 5 Jahren u...
# 27                                                 NaN
# 28    Oktober 2009 für eine Reststrafe von 37 Tagen...
# 29    März 2009 für eine Freiheitsstrafe von 136 Ta...
# 30                                                 NaN
# 31    Der Beschuldigte wird bestraft mit 3 Jahren F...
# 32    Der Beschuldigte wird bestraft mit 2 Jahren F...
# 33    Der Beschuldigte wird bestraft mit 3 1/3 Jahr...
# 34    Der Beschuldigte wird bestraft mit 4 Jahren F...
# 35    Der Beschuldigte wird bestraft mit 3 ½ Jahren...
# ..                                                 ...
# 98    Der Beschuldigte wird bestraft mit 24 Monaten...
# 99    Der Beschuldigte wird bestraft mit 32 Monaten...
# 100   123 StGB von einem Tagessatz Geldstrafe bis z...
# 101   Januar 2013 ausgefällten Freiheitsstrafe wird...
# 102                                                NaN
# 103   Der Beschuldigte wird bestraft mit einer Frei...
# 104   Der Beschuldigte wird bestraft mit 4 Jahren F...
# 105   Der Beschuldigte wird bestraft mit 9 Jahren F...
# 106   Der Beschuldigte wird bestraft mit 21 Monaten...
# 107   45 StGB); Analoges gilt für die bedingte \n\n...
# 108    Der Beschuldigte wird bestraft mit einer Fre...
# 109   Der Beschuldigte wird bestraft mit einer Frei...
# 110   Der Beschuldigte wird bestraft mit 4 Monaten ...
# 111                                                NaN
# 112   Der Vollzug der Freiheitsstrafe wird aufgesch...
# 113                                                NaN
# 114                                                NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...
# 116   Der Beschuldigte wird bestraft mit 4 Jahren u...
# 117   Der Beschuldigte wird bestraft mit 44 Monaten...
# 118                                                NaN
# 119   Der Beschuldigte wird bestraft mit 30 Monaten...
# 120   Der Beschuldigte wird bestraft mit 30 Monaten...
# 121   Die Beschuldigte wird bestraft mit 16 Monaten...
# 122  _____ wird bestraft mit 3 Jahren Freiheitsstra...
# 123   Der Beschuldigte wird bestraft mit einer Frei...
# 124   Der Beschuldigte wird bestraft mit 4 Jahren F...
# 125   Der Beschuldigte wird bestraft mit 3 Jahren F...
# 126   Der Beschuldigte wird bestraft mit 4 ⅔ Jahren...
# 127   Der Beschuldigte sei – zusätzlich zur erstins...
#
# [120 rows x 9 columns]

# %%
df_new['exact_punish'] = df_new.punish.str.extract("(\d+? [A-Z]\w+)")
df_new
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                       author  \
# 2                        lic.iur. S. Janssen
# 3                               Dr. Bischoff
# 4                         lic. iur. N. Burri
# 6                       lic.iur. C. Semadeni
# 8                                  T. Müller
# 9                      lic. iur. T. Walthert
# 10    Lichtensteiger Beat Obergericht Zürich
# 12                             Maya Bertschi
# 13                         lic. iur. R. Naef
# 15                   lic.iur. E. Leuenberger
# 16                                 T. Müller
# 17   Brühwiler Daniela Bezirksgericht Zürich
# 18                        lic.iur. C. Laufer
# 19                   lic.iur. E. Leuenberger
# 20                   lic.iur. E. Leuenberger
# 21                   lic.iur. E. Leuenberger
# 22                   lic. iur. Haike Aardoom
# 23                           Claudia Grieder
# 24                   lic.iur. E. Leuenberger
# 25                       lic.iur. B. Stiefel
# 26                       R. Affolter-Fischer
# 27                        lic. iur. J. Stark
# 28                    lic. iur. M. Langmeier
# 29                               B. Bosshard
# 30                 Dr. iur. Patrick Bischoff
# 31                       lic. iur. S. Oswald
# 32                         lic.iur. C. Brenn
# 33                             Maya Bertschi
# 34                            Dr. S. Janssen
# 35                        lic.iur. A. Hafner
# ..                                       ...
# 98                                  P. Ernst
# 99                                  P. Ernst
# 100                           S. Kümin Grell
# 101                     lic. iur. Ch. Spiess
# 102                       lic.iur. A. Hafner
# 103                              C. von Moos
# 104                       S. Gorisek-Lentini
# 105       lic.iur. S. Hürlimann Winterhalter
# 106                                S. Neukom
# 107                              B. Bosshard
# 108                               S. Bärtsch
# 109                lic.iur. B. Wasser-Keller
# 110                          lic.iur. B. Gut
# 111                              C. von Moos
# 112                              B. Bosshard
# 113                       S. Gorisek-Lentini
# 114                               S. Bärtsch
# 115                          Claudia Grieder
# 116                    lic.iur. L. Chitvanni
# 117                      lic.iur. B. Stiefel
# 118                              B. Bosshard
# 119                               B. Schärer
# 120                               B. Schärer
# 121                     lic. iur. St. Volken
# 122                              B. Bosshard
# 123                      lic.iur. B. Stiefel
# 124                                S. Maurer
# 125                          lic.iur. B. Gut
# 126                       S. Gorisek-Lentini
# 127                        lic.iur. C. Brenn
#
#                                              judgement  \
# 2    Es wird beschlossen: \n\n1. Es wird festgestel...
# 3                                                   \n
# 4    Es wird beschlossen: \n\n1. Auf die Berufung d...
# 6                                                   \n
# 8    Es wird beschlossen: \n\n1. Es wird festgestel...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird beschlossen: \n\n1. Es wird festgestel...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18                                                  \n
# 19                                                  \n
# 20                                                  \n
# 21   Es wird beschlossen: \n\n1. Es wird festgestel...
# 22                                                  \n
# 23   Es wird beschlossen: \n\n1. Es wird festgestel...
# 24   Es wird beschlossen: \n\n1. Auf die Anklage be...
# 25   Es wird beschlossen: \n\n1. Auf die selbständi...
# 26   Es wird beschlossen: \n\n1. Es wird festgestel...
# 27                                                  \n
# 28   Es wird beschlossen: \n\n1. Es wird festgestel...
# 29   Es wird beschlossen: \n\n1. Es wird festgestel...
# 30                                                  \n
# 31   Es wird beschlossen: \n\n1. Es wird festgestel...
# 32                                                  \n
# 33                                                  \n
# 34   Es wird beschlossen: \n\n1. Es wird festgestel...
# 35   Es wird beschlossen: \n\n1. Es wird festgestel...
# ..                                                 ...
# 98   Es wird beschlossen: \n\n1. Es wird festgestel...
# 99   Es wird beschlossen: \n\n1. Es wird festgestel...
# 100                                                 \n
# 101  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 102  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 103  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 104  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 105  Es wird beschlossen: \n\n1. Das Gesuch des Bes...
# 106                                                 \n
# 107  Es wird beschlossen: \n\n1. Auf die Anklage be...
# 108  Es wird beschlossen: \n\n1. Es wird festgestel...
# 109  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 110  Es wird beschlossen: \n\n1. In Bezug auf die v...
# 111  Es wird beschlossen: \n\n1. Es wird festgestel...
# 112  Es wird beschlossen: \n\n1. Es wird festgestel...
# 113  Es wird beschlossen: \n\n1. Es wird festgestel...
# 114  Es wird beschlossen: \n\n1. Es wird festgestel...
# 115  Es wird beschlossen: \n\n1. Es wird festgestel...
# 116  Es wird beschlossen:  \n\n1. Es wird festgeste...
# 117  Es wird beschlossen: \n\n1. Prozess Nr. DG1600...
# 118  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 119  Es wird beschlossen: \n\n1. Es wird festgestel...
# 120  Es wird beschlossen: \n\n1. Es wird festgestel...
# 121  Es wird beschlossen: \n\n1. Es wird festgestel...
# 122  Es wird beschlossen: \n\n1. Es wird festgestel...
# 123                                                 \n
# 124  Es wird beschlossen: \n\n1. Es wird festgestel...
# 125                                                 \n
# 126  Es wird beschlossen: \n\n1. Es wird festgestel...
# 127  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                             judgement1  \
# 2    Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                   \n
# 4    Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 6                                                   \n
# 8    Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird erkannt: \n\n1. Der Angeklagte B._____...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18   Es wird erkannt: \n\n1. Der Beschuldigte ist d...
# 19                                                  \n
# 20                                                  \n
# 21   Es wird erkannt:  \n\n1. Der Beschuldigte A.__...
# 22   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 23   Es wird erkannt: \n\n1. Es wird eine stationär...
# 24   Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 25   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 26   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 27                                                  \n
# 28   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 29   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 30                                                  \n
# 31   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 32   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 33   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 34   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 35   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# ..                                                 ...
# 98   Es wird erkannt: \n\n1. Der Beschuldigte ist f...
# 99   Es wird erkannt: \n\n1. a) Der Beschuldigte A....
# 100  Es wird erkannt: \n\n1. Die Beschuldigte ist s...
# 101  Es wird erkannt: \n\n1. Es wird festgestellt, ...
# 102  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 103  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 104  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 105  Es wird erkannt: \n\n1. Bezüglich der Anklagev...
# 106  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 107  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 108  Es wird erkannt: \n\n1.  Das Verfahren gegen d...
# 109  Es wird erkannt: \n\n1. Der Beschuldigte F.___...
# 110  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 111  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 112  Es wird erkannt: \n\n1. Der beschuldigte Jugen...
# 113  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 114  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 115  Es wird erkannt: \n\n1. Dem Beschuldigten wird...
# 116  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 117  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 118  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 119  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 120  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 121  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 122  Es wird erkannt: \n\n1. Der Beschuldigte E.___...
# 123  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 124  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 125  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 126  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 127  Es wird erkannt: \n\n1. Der Beschuldigte ist d...
#
#                                             judgement2  \
# 2                                                   \n
# 3    Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4    Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 6    Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 8    Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 9    Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 10   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 12   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 13   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 15   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 16   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 17   Das Gericht erkennt: \n\n1. Der Angeklagte wir...
# 18                                                  \n
# 19   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 20   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 21                                                  \n
# 22                                                  \n
# 23   Das Gericht erkennt: \n\n1. Es wird festgestel...
# 24   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 25                                                  \n
# 26                                                  \n
# 27                                                  \n
# 28   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 29                                                  \n
# 30   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 31                                                  \n
# 32                                                  \n
# 33   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 34                                                  \n
# 35                                                  \n
# ..                                                 ...
# 98                                                  \n
# 99                                                  \n
# 100                                                 \n
# 101                                                 \n
# 102                                                 \n
# 103                                                 \n
# 104                                                 \n
# 105                                                 \n
# 106                                                 \n
# 107                                                 \n
# 108                                                 \n
# 109                                                 \n
# 110                                                 \n
# 111                                                 \n
# 112                                                 \n
# 113                                                 \n
# 114                                                 \n
# 115  Das Gericht erkennt: \n\n1. Der Beschuldigte B...
# 116                                                 \n
# 117                                                 \n
# 118                                                 \n
# 119                                                 \n
# 120                                                 \n
# 121                                                 \n
# 122                                                 \n
# 123                                                 \n
# 124                                                 \n
# 125                                                 \n
# 126                                                 \n
# 127                                                 \n
#
#                                        title                  year  guilty  \
# 2    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                    Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 6    Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 8                    Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
# 9                    Dispositiv allgemein SB  2014-10-30T20:46:58Z   False
# 10                                       NaN  2014-10-29T19:22:10Z   False
# 12             Antragsformular Freispruch SB  2014-10-29T18:08:51Z   False
# 13                   Dispositiv allgemein SB  2014-10-30T20:47:32Z   False
# 15   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:42:39Z   False
# 16         Antrag Schuldspruch (ausführlich)  2014-10-29T20:11:04Z   False
# 17   Antragsformular/Dispositiv allgemein SE  2014-10-29T18:00:11Z   False
# 18                   Dispositiv allgemein SB  2014-10-29T18:16:21Z   False
# 19   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:51Z   False
# 20   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:12:52Z   False
# 21                       Antrag Schuldspruch  2014-10-29T18:40:36Z   False
# 22                       Antrag Schuldspruch  2014-10-29T19:59:27Z   False
# 23                         Antrag Freispruch  2014-10-29T18:28:07Z   False
# 24   Antragsformular/Dispositiv allgemein SB  2014-10-29T20:17:20Z   False
# 25                   Dispositiv allgemein SB  2014-10-30T18:25:47Z   False
# 26                       Antrag Schuldspruch  2014-10-29T21:03:30Z   False
# 27                         Antrag Freispruch  2014-10-29T19:02:46Z   False
# 28         Antrag Schuldspruch (ausführlich)  2014-10-29T19:27:24Z   False
# 29                   Dispositiv allgemein SB  2014-10-29T19:15:51Z   False
# 30             Urteilsdispositiv SB (normal)  2014-10-29T18:42:38Z   False
# 31                   Dispositiv allgemein SB  2014-10-29T20:19:08Z   False
# 32                       Antrag Schuldspruch  2014-10-29T19:28:57Z   False
# 33   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:47Z   False
# 34                       Antrag Schuldspruch  2014-10-29T20:55:39Z   False
# 35                       Antrag Schuldspruch  2014-10-29T20:14:25Z   False
# ..                                       ...                   ...     ...
# 98                       Antrag Schuldspruch  2016-12-23T07:31:22Z   False
# 99                       Antrag Schuldspruch  2018-11-14T10:31:11Z   False
# 100                      Antrag Schuldspruch  2017-12-06T07:47:37Z   False
# 101                  Dispositiv allgemein SB  2016-11-30T07:39:42Z   False
# 102                        Antrag Freispruch  2017-06-07T04:45:50Z   False
# 103                      Antrag Schuldspruch  2018-12-12T07:10:06Z   False
# 104                  Dispositiv allgemein SB  2018-03-07T08:59:31Z   False
# 105        Antrag Schuldspruch (ausführlich)  2017-03-01T17:47:22Z   False
# 106                      Antrag Schuldspruch  2017-08-23T08:02:23Z   False
# 107                  Dispositiv allgemein SB  2018-04-04T08:53:13Z   False
# 108        Antrag Schuldspruch (ausführlich)  2019-01-02T18:51:01Z   False
# 109                  Dispositiv allgemein SB  2019-05-22T08:28:38Z   False
# 110                      Antrag Schuldspruch  2017-05-10T07:42:51Z   False
# 111                        Antrag Freispruch  2018-01-24T07:45:11Z   False
# 112                  Dispositiv allgemein SB  2018-03-14T08:38:52Z   False
# 113                  Dispositiv allgemein SB  2018-01-17T07:46:20Z   False
# 114        Antrag Schuldspruch (ausführlich)  2018-07-27T07:48:46Z   False
# 115                      Antrag Schuldspruch  2018-05-16T07:08:54Z   False
# 116                      Antrag Schuldspruch  2018-07-18T08:29:53Z   False
# 117                  Dispositiv allgemein SB  2018-07-12T07:46:51Z   False
# 118                  Dispositiv allgemein SB  2018-09-26T08:11:49Z   False
# 119                  Dispositiv allgemein SB  2018-07-05T07:33:01Z   False
# 120                  Dispositiv allgemein SB  2018-09-26T08:10:56Z   False
# 121        Antrag Schuldspruch (ausführlich)  2019-05-02T08:52:41Z   False
# 122                  Dispositiv allgemein SB  2018-06-13T06:52:17Z   False
# 123                  Dispositiv allgemein SB  2019-01-16T08:21:15Z   False
# 124                      Antrag Schuldspruch  2018-08-22T08:06:42Z   False
# 125                        Antrag Freispruch  2019-07-03T08:04:44Z   False
# 126                  Dispositiv allgemein SB  2019-06-19T08:38:16Z   False
# 127                      Antrag Schuldspruch  2019-06-26T06:54:49Z   False
#
#                                                 punish  \
# 2                                                  NaN
# 3                                                  NaN
# 4     Der Angeklagte wird bestraft mit 17 Monaten F...
# 6     Der Angeklagte wird unter Einbezug der widerr...
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...
# 9     Der Angeklagte wird bestraft mit 36 Monaten F...
# 10    Der Angeklagte wird bestraft mit 7 ½ Jahren F...
# 12                                                 NaN
# 13                                                 NaN
# 15    Der Angeklagte wird bestraft mit 28 Monaten F...
# 16    Februar 2006 ausgefällte, bedingte \n\nFreihe...
# 17    März 2009 ausgefällten Freiheitsstrafe rück-\...
# 18                                                 NaN
# 19    Der Angeklagte wird bestraft mit 6 Jahren Fre...
# 20    Der Angeklagte wird bestraft mit 18 Monaten F...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24    Der Angeklagte wird bestraft mit 10 Jahren Fr...
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28    Der Beschuldigte wird unter Einbezug des wide...
# 29                                                 NaN
# 30    Der Beschuldigte wird bestraft mit 4 ½ Jahren...
# 31                                                 NaN
# 32                                                 NaN
# 33    Der Beschuldigte wird bestraft mit 4 Jahren F...
# 34                                                 NaN
# 35                                                 NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                                                punish1 exact_punish
# 2    _____ wird bestraft mit 18 Monaten Freiheitsst...          NaN
# 3                                                  NaN          NaN
# 4     Der Beschuldigte wird bestraft mit 2 1/2 Jahr...   17 Monaten
# 6                                                  NaN   27 Monaten
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...    12 Jahren
# 9                                                  NaN   36 Monaten
# 10                                                 NaN     336 Tage
# 12                                                 NaN          NaN
# 13                                                 NaN          NaN
# 15                                                 NaN   28 Monaten
# 16                                                 NaN    8 Monaten
# 17                                                 NaN          NaN
# 18    Der Beschuldigte wird bestraft mit 3 ¼ Jahren...          NaN
# 19                                                 NaN     6 Jahren
# 20                                                 NaN   18 Monaten
# 21    Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 22    Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 23                                                 NaN          NaN
# 24    Der Angeklagte wird bestraft mit 14 Jahren Fr...    10 Jahren
# 25    Der Beschuldigte wird bestraft mit 16 Jahren ...          NaN
# 26    Der Beschuldigte wird bestraft mit 5 Jahren u...          NaN
# 27                                                 NaN          NaN
# 28    Oktober 2009 für eine Reststrafe von 37 Tagen...     37 Tagen
# 29    März 2009 für eine Freiheitsstrafe von 136 Ta...          NaN
# 30                                                 NaN        1 Tag
# 31    Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 32    Der Beschuldigte wird bestraft mit 2 Jahren F...          NaN
# 33    Der Beschuldigte wird bestraft mit 3 1/3 Jahr...     4 Jahren
# 34    Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 35    Der Beschuldigte wird bestraft mit 3 ½ Jahren...          NaN
# ..                                                 ...          ...
# 98    Der Beschuldigte wird bestraft mit 24 Monaten...          NaN
# 99    Der Beschuldigte wird bestraft mit 32 Monaten...          NaN
# 100   123 StGB von einem Tagessatz Geldstrafe bis z...          NaN
# 101   Januar 2013 ausgefällten Freiheitsstrafe wird...          NaN
# 102                                                NaN          NaN
# 103   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 104   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 105   Der Beschuldigte wird bestraft mit 9 Jahren F...          NaN
# 106   Der Beschuldigte wird bestraft mit 21 Monaten...          NaN
# 107   45 StGB); Analoges gilt für die bedingte \n\n...          NaN
# 108    Der Beschuldigte wird bestraft mit einer Fre...          NaN
# 109   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 110   Der Beschuldigte wird bestraft mit 4 Monaten ...          NaN
# 111                                                NaN          NaN
# 112   Der Vollzug der Freiheitsstrafe wird aufgesch...          NaN
# 113                                                NaN          NaN
# 114                                                NaN          NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...          NaN
# 116   Der Beschuldigte wird bestraft mit 4 Jahren u...          NaN
# 117   Der Beschuldigte wird bestraft mit 44 Monaten...          NaN
# 118                                                NaN          NaN
# 119   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 120   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 121   Die Beschuldigte wird bestraft mit 16 Monaten...          NaN
# 122  _____ wird bestraft mit 3 Jahren Freiheitsstra...          NaN
# 123   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 124   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 125   Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 126   Der Beschuldigte wird bestraft mit 4 ⅔ Jahren...          NaN
# 127   Der Beschuldigte sei – zusätzlich zur erstins...          NaN
#
# [120 rows x 10 columns]

# %%
df_new['exact_punish1'] = df_new.punish1.str.extract("(\d+? [A-Z]\w+)")
df_new
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                       author  \
# 2                        lic.iur. S. Janssen
# 3                               Dr. Bischoff
# 4                         lic. iur. N. Burri
# 6                       lic.iur. C. Semadeni
# 8                                  T. Müller
# 9                      lic. iur. T. Walthert
# 10    Lichtensteiger Beat Obergericht Zürich
# 12                             Maya Bertschi
# 13                         lic. iur. R. Naef
# 15                   lic.iur. E. Leuenberger
# 16                                 T. Müller
# 17   Brühwiler Daniela Bezirksgericht Zürich
# 18                        lic.iur. C. Laufer
# 19                   lic.iur. E. Leuenberger
# 20                   lic.iur. E. Leuenberger
# 21                   lic.iur. E. Leuenberger
# 22                   lic. iur. Haike Aardoom
# 23                           Claudia Grieder
# 24                   lic.iur. E. Leuenberger
# 25                       lic.iur. B. Stiefel
# 26                       R. Affolter-Fischer
# 27                        lic. iur. J. Stark
# 28                    lic. iur. M. Langmeier
# 29                               B. Bosshard
# 30                 Dr. iur. Patrick Bischoff
# 31                       lic. iur. S. Oswald
# 32                         lic.iur. C. Brenn
# 33                             Maya Bertschi
# 34                            Dr. S. Janssen
# 35                        lic.iur. A. Hafner
# ..                                       ...
# 98                                  P. Ernst
# 99                                  P. Ernst
# 100                           S. Kümin Grell
# 101                     lic. iur. Ch. Spiess
# 102                       lic.iur. A. Hafner
# 103                              C. von Moos
# 104                       S. Gorisek-Lentini
# 105       lic.iur. S. Hürlimann Winterhalter
# 106                                S. Neukom
# 107                              B. Bosshard
# 108                               S. Bärtsch
# 109                lic.iur. B. Wasser-Keller
# 110                          lic.iur. B. Gut
# 111                              C. von Moos
# 112                              B. Bosshard
# 113                       S. Gorisek-Lentini
# 114                               S. Bärtsch
# 115                          Claudia Grieder
# 116                    lic.iur. L. Chitvanni
# 117                      lic.iur. B. Stiefel
# 118                              B. Bosshard
# 119                               B. Schärer
# 120                               B. Schärer
# 121                     lic. iur. St. Volken
# 122                              B. Bosshard
# 123                      lic.iur. B. Stiefel
# 124                                S. Maurer
# 125                          lic.iur. B. Gut
# 126                       S. Gorisek-Lentini
# 127                        lic.iur. C. Brenn
#
#                                              judgement  \
# 2    Es wird beschlossen: \n\n1. Es wird festgestel...
# 3                                                   \n
# 4    Es wird beschlossen: \n\n1. Auf die Berufung d...
# 6                                                   \n
# 8    Es wird beschlossen: \n\n1. Es wird festgestel...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird beschlossen: \n\n1. Es wird festgestel...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18                                                  \n
# 19                                                  \n
# 20                                                  \n
# 21   Es wird beschlossen: \n\n1. Es wird festgestel...
# 22                                                  \n
# 23   Es wird beschlossen: \n\n1. Es wird festgestel...
# 24   Es wird beschlossen: \n\n1. Auf die Anklage be...
# 25   Es wird beschlossen: \n\n1. Auf die selbständi...
# 26   Es wird beschlossen: \n\n1. Es wird festgestel...
# 27                                                  \n
# 28   Es wird beschlossen: \n\n1. Es wird festgestel...
# 29   Es wird beschlossen: \n\n1. Es wird festgestel...
# 30                                                  \n
# 31   Es wird beschlossen: \n\n1. Es wird festgestel...
# 32                                                  \n
# 33                                                  \n
# 34   Es wird beschlossen: \n\n1. Es wird festgestel...
# 35   Es wird beschlossen: \n\n1. Es wird festgestel...
# ..                                                 ...
# 98   Es wird beschlossen: \n\n1. Es wird festgestel...
# 99   Es wird beschlossen: \n\n1. Es wird festgestel...
# 100                                                 \n
# 101  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 102  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 103  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 104  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 105  Es wird beschlossen: \n\n1. Das Gesuch des Bes...
# 106                                                 \n
# 107  Es wird beschlossen: \n\n1. Auf die Anklage be...
# 108  Es wird beschlossen: \n\n1. Es wird festgestel...
# 109  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 110  Es wird beschlossen: \n\n1. In Bezug auf die v...
# 111  Es wird beschlossen: \n\n1. Es wird festgestel...
# 112  Es wird beschlossen: \n\n1. Es wird festgestel...
# 113  Es wird beschlossen: \n\n1. Es wird festgestel...
# 114  Es wird beschlossen: \n\n1. Es wird festgestel...
# 115  Es wird beschlossen: \n\n1. Es wird festgestel...
# 116  Es wird beschlossen:  \n\n1. Es wird festgeste...
# 117  Es wird beschlossen: \n\n1. Prozess Nr. DG1600...
# 118  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 119  Es wird beschlossen: \n\n1. Es wird festgestel...
# 120  Es wird beschlossen: \n\n1. Es wird festgestel...
# 121  Es wird beschlossen: \n\n1. Es wird festgestel...
# 122  Es wird beschlossen: \n\n1. Es wird festgestel...
# 123                                                 \n
# 124  Es wird beschlossen: \n\n1. Es wird festgestel...
# 125                                                 \n
# 126  Es wird beschlossen: \n\n1. Es wird festgestel...
# 127  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                             judgement1  \
# 2    Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                   \n
# 4    Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 6                                                   \n
# 8    Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird erkannt: \n\n1. Der Angeklagte B._____...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18   Es wird erkannt: \n\n1. Der Beschuldigte ist d...
# 19                                                  \n
# 20                                                  \n
# 21   Es wird erkannt:  \n\n1. Der Beschuldigte A.__...
# 22   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 23   Es wird erkannt: \n\n1. Es wird eine stationär...
# 24   Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 25   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 26   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 27                                                  \n
# 28   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 29   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 30                                                  \n
# 31   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 32   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 33   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 34   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 35   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# ..                                                 ...
# 98   Es wird erkannt: \n\n1. Der Beschuldigte ist f...
# 99   Es wird erkannt: \n\n1. a) Der Beschuldigte A....
# 100  Es wird erkannt: \n\n1. Die Beschuldigte ist s...
# 101  Es wird erkannt: \n\n1. Es wird festgestellt, ...
# 102  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 103  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 104  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 105  Es wird erkannt: \n\n1. Bezüglich der Anklagev...
# 106  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 107  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 108  Es wird erkannt: \n\n1.  Das Verfahren gegen d...
# 109  Es wird erkannt: \n\n1. Der Beschuldigte F.___...
# 110  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 111  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 112  Es wird erkannt: \n\n1. Der beschuldigte Jugen...
# 113  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 114  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 115  Es wird erkannt: \n\n1. Dem Beschuldigten wird...
# 116  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 117  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 118  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 119  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 120  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 121  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 122  Es wird erkannt: \n\n1. Der Beschuldigte E.___...
# 123  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 124  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 125  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 126  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 127  Es wird erkannt: \n\n1. Der Beschuldigte ist d...
#
#                                             judgement2  \
# 2                                                   \n
# 3    Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4    Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 6    Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 8    Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 9    Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 10   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 12   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 13   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 15   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 16   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 17   Das Gericht erkennt: \n\n1. Der Angeklagte wir...
# 18                                                  \n
# 19   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 20   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 21                                                  \n
# 22                                                  \n
# 23   Das Gericht erkennt: \n\n1. Es wird festgestel...
# 24   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 25                                                  \n
# 26                                                  \n
# 27                                                  \n
# 28   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 29                                                  \n
# 30   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 31                                                  \n
# 32                                                  \n
# 33   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 34                                                  \n
# 35                                                  \n
# ..                                                 ...
# 98                                                  \n
# 99                                                  \n
# 100                                                 \n
# 101                                                 \n
# 102                                                 \n
# 103                                                 \n
# 104                                                 \n
# 105                                                 \n
# 106                                                 \n
# 107                                                 \n
# 108                                                 \n
# 109                                                 \n
# 110                                                 \n
# 111                                                 \n
# 112                                                 \n
# 113                                                 \n
# 114                                                 \n
# 115  Das Gericht erkennt: \n\n1. Der Beschuldigte B...
# 116                                                 \n
# 117                                                 \n
# 118                                                 \n
# 119                                                 \n
# 120                                                 \n
# 121                                                 \n
# 122                                                 \n
# 123                                                 \n
# 124                                                 \n
# 125                                                 \n
# 126                                                 \n
# 127                                                 \n
#
#                                        title                  year  guilty  \
# 2    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                    Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 6    Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 8                    Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
# 9                    Dispositiv allgemein SB  2014-10-30T20:46:58Z   False
# 10                                       NaN  2014-10-29T19:22:10Z   False
# 12             Antragsformular Freispruch SB  2014-10-29T18:08:51Z   False
# 13                   Dispositiv allgemein SB  2014-10-30T20:47:32Z   False
# 15   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:42:39Z   False
# 16         Antrag Schuldspruch (ausführlich)  2014-10-29T20:11:04Z   False
# 17   Antragsformular/Dispositiv allgemein SE  2014-10-29T18:00:11Z   False
# 18                   Dispositiv allgemein SB  2014-10-29T18:16:21Z   False
# 19   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:51Z   False
# 20   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:12:52Z   False
# 21                       Antrag Schuldspruch  2014-10-29T18:40:36Z   False
# 22                       Antrag Schuldspruch  2014-10-29T19:59:27Z   False
# 23                         Antrag Freispruch  2014-10-29T18:28:07Z   False
# 24   Antragsformular/Dispositiv allgemein SB  2014-10-29T20:17:20Z   False
# 25                   Dispositiv allgemein SB  2014-10-30T18:25:47Z   False
# 26                       Antrag Schuldspruch  2014-10-29T21:03:30Z   False
# 27                         Antrag Freispruch  2014-10-29T19:02:46Z   False
# 28         Antrag Schuldspruch (ausführlich)  2014-10-29T19:27:24Z   False
# 29                   Dispositiv allgemein SB  2014-10-29T19:15:51Z   False
# 30             Urteilsdispositiv SB (normal)  2014-10-29T18:42:38Z   False
# 31                   Dispositiv allgemein SB  2014-10-29T20:19:08Z   False
# 32                       Antrag Schuldspruch  2014-10-29T19:28:57Z   False
# 33   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:47Z   False
# 34                       Antrag Schuldspruch  2014-10-29T20:55:39Z   False
# 35                       Antrag Schuldspruch  2014-10-29T20:14:25Z   False
# ..                                       ...                   ...     ...
# 98                       Antrag Schuldspruch  2016-12-23T07:31:22Z   False
# 99                       Antrag Schuldspruch  2018-11-14T10:31:11Z   False
# 100                      Antrag Schuldspruch  2017-12-06T07:47:37Z   False
# 101                  Dispositiv allgemein SB  2016-11-30T07:39:42Z   False
# 102                        Antrag Freispruch  2017-06-07T04:45:50Z   False
# 103                      Antrag Schuldspruch  2018-12-12T07:10:06Z   False
# 104                  Dispositiv allgemein SB  2018-03-07T08:59:31Z   False
# 105        Antrag Schuldspruch (ausführlich)  2017-03-01T17:47:22Z   False
# 106                      Antrag Schuldspruch  2017-08-23T08:02:23Z   False
# 107                  Dispositiv allgemein SB  2018-04-04T08:53:13Z   False
# 108        Antrag Schuldspruch (ausführlich)  2019-01-02T18:51:01Z   False
# 109                  Dispositiv allgemein SB  2019-05-22T08:28:38Z   False
# 110                      Antrag Schuldspruch  2017-05-10T07:42:51Z   False
# 111                        Antrag Freispruch  2018-01-24T07:45:11Z   False
# 112                  Dispositiv allgemein SB  2018-03-14T08:38:52Z   False
# 113                  Dispositiv allgemein SB  2018-01-17T07:46:20Z   False
# 114        Antrag Schuldspruch (ausführlich)  2018-07-27T07:48:46Z   False
# 115                      Antrag Schuldspruch  2018-05-16T07:08:54Z   False
# 116                      Antrag Schuldspruch  2018-07-18T08:29:53Z   False
# 117                  Dispositiv allgemein SB  2018-07-12T07:46:51Z   False
# 118                  Dispositiv allgemein SB  2018-09-26T08:11:49Z   False
# 119                  Dispositiv allgemein SB  2018-07-05T07:33:01Z   False
# 120                  Dispositiv allgemein SB  2018-09-26T08:10:56Z   False
# 121        Antrag Schuldspruch (ausführlich)  2019-05-02T08:52:41Z   False
# 122                  Dispositiv allgemein SB  2018-06-13T06:52:17Z   False
# 123                  Dispositiv allgemein SB  2019-01-16T08:21:15Z   False
# 124                      Antrag Schuldspruch  2018-08-22T08:06:42Z   False
# 125                        Antrag Freispruch  2019-07-03T08:04:44Z   False
# 126                  Dispositiv allgemein SB  2019-06-19T08:38:16Z   False
# 127                      Antrag Schuldspruch  2019-06-26T06:54:49Z   False
#
#                                                 punish  \
# 2                                                  NaN
# 3                                                  NaN
# 4     Der Angeklagte wird bestraft mit 17 Monaten F...
# 6     Der Angeklagte wird unter Einbezug der widerr...
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...
# 9     Der Angeklagte wird bestraft mit 36 Monaten F...
# 10    Der Angeklagte wird bestraft mit 7 ½ Jahren F...
# 12                                                 NaN
# 13                                                 NaN
# 15    Der Angeklagte wird bestraft mit 28 Monaten F...
# 16    Februar 2006 ausgefällte, bedingte \n\nFreihe...
# 17    März 2009 ausgefällten Freiheitsstrafe rück-\...
# 18                                                 NaN
# 19    Der Angeklagte wird bestraft mit 6 Jahren Fre...
# 20    Der Angeklagte wird bestraft mit 18 Monaten F...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24    Der Angeklagte wird bestraft mit 10 Jahren Fr...
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28    Der Beschuldigte wird unter Einbezug des wide...
# 29                                                 NaN
# 30    Der Beschuldigte wird bestraft mit 4 ½ Jahren...
# 31                                                 NaN
# 32                                                 NaN
# 33    Der Beschuldigte wird bestraft mit 4 Jahren F...
# 34                                                 NaN
# 35                                                 NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                                                punish1 exact_punish  \
# 2    _____ wird bestraft mit 18 Monaten Freiheitsst...          NaN
# 3                                                  NaN          NaN
# 4     Der Beschuldigte wird bestraft mit 2 1/2 Jahr...   17 Monaten
# 6                                                  NaN   27 Monaten
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...    12 Jahren
# 9                                                  NaN   36 Monaten
# 10                                                 NaN     336 Tage
# 12                                                 NaN          NaN
# 13                                                 NaN          NaN
# 15                                                 NaN   28 Monaten
# 16                                                 NaN    8 Monaten
# 17                                                 NaN          NaN
# 18    Der Beschuldigte wird bestraft mit 3 ¼ Jahren...          NaN
# 19                                                 NaN     6 Jahren
# 20                                                 NaN   18 Monaten
# 21    Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 22    Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 23                                                 NaN          NaN
# 24    Der Angeklagte wird bestraft mit 14 Jahren Fr...    10 Jahren
# 25    Der Beschuldigte wird bestraft mit 16 Jahren ...          NaN
# 26    Der Beschuldigte wird bestraft mit 5 Jahren u...          NaN
# 27                                                 NaN          NaN
# 28    Oktober 2009 für eine Reststrafe von 37 Tagen...     37 Tagen
# 29    März 2009 für eine Freiheitsstrafe von 136 Ta...          NaN
# 30                                                 NaN        1 Tag
# 31    Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 32    Der Beschuldigte wird bestraft mit 2 Jahren F...          NaN
# 33    Der Beschuldigte wird bestraft mit 3 1/3 Jahr...     4 Jahren
# 34    Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 35    Der Beschuldigte wird bestraft mit 3 ½ Jahren...          NaN
# ..                                                 ...          ...
# 98    Der Beschuldigte wird bestraft mit 24 Monaten...          NaN
# 99    Der Beschuldigte wird bestraft mit 32 Monaten...          NaN
# 100   123 StGB von einem Tagessatz Geldstrafe bis z...          NaN
# 101   Januar 2013 ausgefällten Freiheitsstrafe wird...          NaN
# 102                                                NaN          NaN
# 103   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 104   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 105   Der Beschuldigte wird bestraft mit 9 Jahren F...          NaN
# 106   Der Beschuldigte wird bestraft mit 21 Monaten...          NaN
# 107   45 StGB); Analoges gilt für die bedingte \n\n...          NaN
# 108    Der Beschuldigte wird bestraft mit einer Fre...          NaN
# 109   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 110   Der Beschuldigte wird bestraft mit 4 Monaten ...          NaN
# 111                                                NaN          NaN
# 112   Der Vollzug der Freiheitsstrafe wird aufgesch...          NaN
# 113                                                NaN          NaN
# 114                                                NaN          NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...          NaN
# 116   Der Beschuldigte wird bestraft mit 4 Jahren u...          NaN
# 117   Der Beschuldigte wird bestraft mit 44 Monaten...          NaN
# 118                                                NaN          NaN
# 119   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 120   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 121   Die Beschuldigte wird bestraft mit 16 Monaten...          NaN
# 122  _____ wird bestraft mit 3 Jahren Freiheitsstra...          NaN
# 123   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 124   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 125   Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 126   Der Beschuldigte wird bestraft mit 4 ⅔ Jahren...          NaN
# 127   Der Beschuldigte sei – zusätzlich zur erstins...          NaN
#
#     exact_punish1
# 2      18 Monaten
# 3             NaN
# 4        2 Jahren
# 6             NaN
# 8       12 Jahren
# 9             NaN
# 10            NaN
# 12            NaN
# 13            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18       171 Tage
# 19            NaN
# 20            NaN
# 21     13 Monaten
# 22     30 Monaten
# 23            NaN
# 24      14 Jahren
# 25      16 Jahren
# 26       5 Jahren
# 27            NaN
# 28       37 Tagen
# 29      136 Tagen
# 30            NaN
# 31       3 Jahren
# 32       2 Jahren
# 33       3 Jahren
# 34       4 Jahren
# 35       554 Tage
# ..            ...
# 98     24 Monaten
# 99     32 Monaten
# 100      123 StGB
# 101           NaN
# 102           NaN
# 103    22 Monaten
# 104      4 Jahren
# 105      9 Jahren
# 106    21 Monaten
# 107       45 StGB
# 108    40 Monaten
# 109    24 Monaten
# 110     4 Monaten
# 111           NaN
# 112           NaN
# 113           NaN
# 114           NaN
# 115           NaN
# 116      4 Jahren
# 117    44 Monaten
# 118           NaN
# 119    30 Monaten
# 120    30 Monaten
# 121    16 Monaten
# 122      3 Jahren
# 123      4 Jahren
# 124      4 Jahren
# 125      3 Jahren
# 126           NaN
# 127      2 Jahren
#
# [120 rows x 11 columns]

# %%
df_new['number_punish'] = df_new.exact_punish.str.extract("(\d+)")
df_new

df_new['number_punish1'] = df_new.exact_punish1.str.extract("(\d+)")
df_new
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                       author  \
# 2                        lic.iur. S. Janssen
# 3                               Dr. Bischoff
# 4                         lic. iur. N. Burri
# 6                       lic.iur. C. Semadeni
# 8                                  T. Müller
# 9                      lic. iur. T. Walthert
# 10    Lichtensteiger Beat Obergericht Zürich
# 12                             Maya Bertschi
# 13                         lic. iur. R. Naef
# 15                   lic.iur. E. Leuenberger
# 16                                 T. Müller
# 17   Brühwiler Daniela Bezirksgericht Zürich
# 18                        lic.iur. C. Laufer
# 19                   lic.iur. E. Leuenberger
# 20                   lic.iur. E. Leuenberger
# 21                   lic.iur. E. Leuenberger
# 22                   lic. iur. Haike Aardoom
# 23                           Claudia Grieder
# 24                   lic.iur. E. Leuenberger
# 25                       lic.iur. B. Stiefel
# 26                       R. Affolter-Fischer
# 27                        lic. iur. J. Stark
# 28                    lic. iur. M. Langmeier
# 29                               B. Bosshard
# 30                 Dr. iur. Patrick Bischoff
# 31                       lic. iur. S. Oswald
# 32                         lic.iur. C. Brenn
# 33                             Maya Bertschi
# 34                            Dr. S. Janssen
# 35                        lic.iur. A. Hafner
# ..                                       ...
# 98                                  P. Ernst
# 99                                  P. Ernst
# 100                           S. Kümin Grell
# 101                     lic. iur. Ch. Spiess
# 102                       lic.iur. A. Hafner
# 103                              C. von Moos
# 104                       S. Gorisek-Lentini
# 105       lic.iur. S. Hürlimann Winterhalter
# 106                                S. Neukom
# 107                              B. Bosshard
# 108                               S. Bärtsch
# 109                lic.iur. B. Wasser-Keller
# 110                          lic.iur. B. Gut
# 111                              C. von Moos
# 112                              B. Bosshard
# 113                       S. Gorisek-Lentini
# 114                               S. Bärtsch
# 115                          Claudia Grieder
# 116                    lic.iur. L. Chitvanni
# 117                      lic.iur. B. Stiefel
# 118                              B. Bosshard
# 119                               B. Schärer
# 120                               B. Schärer
# 121                     lic. iur. St. Volken
# 122                              B. Bosshard
# 123                      lic.iur. B. Stiefel
# 124                                S. Maurer
# 125                          lic.iur. B. Gut
# 126                       S. Gorisek-Lentini
# 127                        lic.iur. C. Brenn
#
#                                              judgement  \
# 2    Es wird beschlossen: \n\n1. Es wird festgestel...
# 3                                                   \n
# 4    Es wird beschlossen: \n\n1. Auf die Berufung d...
# 6                                                   \n
# 8    Es wird beschlossen: \n\n1. Es wird festgestel...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird beschlossen: \n\n1. Es wird festgestel...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18                                                  \n
# 19                                                  \n
# 20                                                  \n
# 21   Es wird beschlossen: \n\n1. Es wird festgestel...
# 22                                                  \n
# 23   Es wird beschlossen: \n\n1. Es wird festgestel...
# 24   Es wird beschlossen: \n\n1. Auf die Anklage be...
# 25   Es wird beschlossen: \n\n1. Auf die selbständi...
# 26   Es wird beschlossen: \n\n1. Es wird festgestel...
# 27                                                  \n
# 28   Es wird beschlossen: \n\n1. Es wird festgestel...
# 29   Es wird beschlossen: \n\n1. Es wird festgestel...
# 30                                                  \n
# 31   Es wird beschlossen: \n\n1. Es wird festgestel...
# 32                                                  \n
# 33                                                  \n
# 34   Es wird beschlossen: \n\n1. Es wird festgestel...
# 35   Es wird beschlossen: \n\n1. Es wird festgestel...
# ..                                                 ...
# 98   Es wird beschlossen: \n\n1. Es wird festgestel...
# 99   Es wird beschlossen: \n\n1. Es wird festgestel...
# 100                                                 \n
# 101  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 102  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 103  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 104  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 105  Es wird beschlossen: \n\n1. Das Gesuch des Bes...
# 106                                                 \n
# 107  Es wird beschlossen: \n\n1. Auf die Anklage be...
# 108  Es wird beschlossen: \n\n1. Es wird festgestel...
# 109  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 110  Es wird beschlossen: \n\n1. In Bezug auf die v...
# 111  Es wird beschlossen: \n\n1. Es wird festgestel...
# 112  Es wird beschlossen: \n\n1. Es wird festgestel...
# 113  Es wird beschlossen: \n\n1. Es wird festgestel...
# 114  Es wird beschlossen: \n\n1. Es wird festgestel...
# 115  Es wird beschlossen: \n\n1. Es wird festgestel...
# 116  Es wird beschlossen:  \n\n1. Es wird festgeste...
# 117  Es wird beschlossen: \n\n1. Prozess Nr. DG1600...
# 118  Es wird beschlossen: \n\n1. Vom Rückzug der Be...
# 119  Es wird beschlossen: \n\n1. Es wird festgestel...
# 120  Es wird beschlossen: \n\n1. Es wird festgestel...
# 121  Es wird beschlossen: \n\n1. Es wird festgestel...
# 122  Es wird beschlossen: \n\n1. Es wird festgestel...
# 123                                                 \n
# 124  Es wird beschlossen: \n\n1. Es wird festgestel...
# 125                                                 \n
# 126  Es wird beschlossen: \n\n1. Es wird festgestel...
# 127  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                             judgement1  \
# 2    Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 3                                                   \n
# 4    Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 6                                                   \n
# 8    Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 9                                                   \n
# 10                                                  \n
# 12   Es wird erkannt: \n\n1. Der Angeklagte B._____...
# 13                                                  \n
# 15                                                  \n
# 16                                                  \n
# 17                                                  \n
# 18   Es wird erkannt: \n\n1. Der Beschuldigte ist d...
# 19                                                  \n
# 20                                                  \n
# 21   Es wird erkannt:  \n\n1. Der Beschuldigte A.__...
# 22   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 23   Es wird erkannt: \n\n1. Es wird eine stationär...
# 24   Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 25   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 26   Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 27                                                  \n
# 28   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# 29   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 30                                                  \n
# 31   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 32   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 33   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 34   Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 35   Es wird erkannt: \n\n1. Der Beschuldigte wird ...
# ..                                                 ...
# 98   Es wird erkannt: \n\n1. Der Beschuldigte ist f...
# 99   Es wird erkannt: \n\n1. a) Der Beschuldigte A....
# 100  Es wird erkannt: \n\n1. Die Beschuldigte ist s...
# 101  Es wird erkannt: \n\n1. Es wird festgestellt, ...
# 102  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 103  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 104  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 105  Es wird erkannt: \n\n1. Bezüglich der Anklagev...
# 106  Es wird erkannt: \n\n1. Der Beschuldigte B.___...
# 107  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 108  Es wird erkannt: \n\n1.  Das Verfahren gegen d...
# 109  Es wird erkannt: \n\n1. Der Beschuldigte F.___...
# 110  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 111  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 112  Es wird erkannt: \n\n1. Der beschuldigte Jugen...
# 113  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 114  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 115  Es wird erkannt: \n\n1. Dem Beschuldigten wird...
# 116  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 117  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 118  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 119  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 120  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 121  Es wird erkannt: \n\n1. Die Beschuldigte B.___...
# 122  Es wird erkannt: \n\n1. Der Beschuldigte E.___...
# 123  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 124  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 125  Es wird erkannt: \n\n1. Der Beschuldigte ist s...
# 126  Es wird erkannt: \n\n1. Der Beschuldigte A.___...
# 127  Es wird erkannt: \n\n1. Der Beschuldigte ist d...
#
#                                             judgement2  \
# 2                                                   \n
# 3    Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 4    Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 6    Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 8    Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 9    Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 10   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 12   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 13   Das Gericht erkennt: \n\n1. Der Angeklagte ist...
# 15   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 16   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 17   Das Gericht erkennt: \n\n1. Der Angeklagte wir...
# 18                                                  \n
# 19   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 20   Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 21                                                  \n
# 22                                                  \n
# 23   Das Gericht erkennt: \n\n1. Es wird festgestel...
# 24   Das Gericht erkennt: \n\n1. Der Angeklagte A._...
# 25                                                  \n
# 26                                                  \n
# 27                                                  \n
# 28   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 29                                                  \n
# 30   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 31                                                  \n
# 32                                                  \n
# 33   Das Gericht erkennt: \n\n1. Der Beschuldigte i...
# 34                                                  \n
# 35                                                  \n
# ..                                                 ...
# 98                                                  \n
# 99                                                  \n
# 100                                                 \n
# 101                                                 \n
# 102                                                 \n
# 103                                                 \n
# 104                                                 \n
# 105                                                 \n
# 106                                                 \n
# 107                                                 \n
# 108                                                 \n
# 109                                                 \n
# 110                                                 \n
# 111                                                 \n
# 112                                                 \n
# 113                                                 \n
# 114                                                 \n
# 115  Das Gericht erkennt: \n\n1. Der Beschuldigte B...
# 116                                                 \n
# 117                                                 \n
# 118                                                 \n
# 119                                                 \n
# 120                                                 \n
# 121                                                 \n
# 122                                                 \n
# 123                                                 \n
# 124                                                 \n
# 125                                                 \n
# 126                                                 \n
# 127                                                 \n
#
#                                        title                  year  guilty  \
# 2    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 3                    Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 4    Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 6    Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 8                    Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
# 9                    Dispositiv allgemein SB  2014-10-30T20:46:58Z   False
# 10                                       NaN  2014-10-29T19:22:10Z   False
# 12             Antragsformular Freispruch SB  2014-10-29T18:08:51Z   False
# 13                   Dispositiv allgemein SB  2014-10-30T20:47:32Z   False
# 15   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:42:39Z   False
# 16         Antrag Schuldspruch (ausführlich)  2014-10-29T20:11:04Z   False
# 17   Antragsformular/Dispositiv allgemein SE  2014-10-29T18:00:11Z   False
# 18                   Dispositiv allgemein SB  2014-10-29T18:16:21Z   False
# 19   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:51Z   False
# 20   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:12:52Z   False
# 21                       Antrag Schuldspruch  2014-10-29T18:40:36Z   False
# 22                       Antrag Schuldspruch  2014-10-29T19:59:27Z   False
# 23                         Antrag Freispruch  2014-10-29T18:28:07Z   False
# 24   Antragsformular/Dispositiv allgemein SB  2014-10-29T20:17:20Z   False
# 25                   Dispositiv allgemein SB  2014-10-30T18:25:47Z   False
# 26                       Antrag Schuldspruch  2014-10-29T21:03:30Z   False
# 27                         Antrag Freispruch  2014-10-29T19:02:46Z   False
# 28         Antrag Schuldspruch (ausführlich)  2014-10-29T19:27:24Z   False
# 29                   Dispositiv allgemein SB  2014-10-29T19:15:51Z   False
# 30             Urteilsdispositiv SB (normal)  2014-10-29T18:42:38Z   False
# 31                   Dispositiv allgemein SB  2014-10-29T20:19:08Z   False
# 32                       Antrag Schuldspruch  2014-10-29T19:28:57Z   False
# 33   Antragsformular/Dispositiv allgemein SB  2014-10-29T19:57:47Z   False
# 34                       Antrag Schuldspruch  2014-10-29T20:55:39Z   False
# 35                       Antrag Schuldspruch  2014-10-29T20:14:25Z   False
# ..                                       ...                   ...     ...
# 98                       Antrag Schuldspruch  2016-12-23T07:31:22Z   False
# 99                       Antrag Schuldspruch  2018-11-14T10:31:11Z   False
# 100                      Antrag Schuldspruch  2017-12-06T07:47:37Z   False
# 101                  Dispositiv allgemein SB  2016-11-30T07:39:42Z   False
# 102                        Antrag Freispruch  2017-06-07T04:45:50Z   False
# 103                      Antrag Schuldspruch  2018-12-12T07:10:06Z   False
# 104                  Dispositiv allgemein SB  2018-03-07T08:59:31Z   False
# 105        Antrag Schuldspruch (ausführlich)  2017-03-01T17:47:22Z   False
# 106                      Antrag Schuldspruch  2017-08-23T08:02:23Z   False
# 107                  Dispositiv allgemein SB  2018-04-04T08:53:13Z   False
# 108        Antrag Schuldspruch (ausführlich)  2019-01-02T18:51:01Z   False
# 109                  Dispositiv allgemein SB  2019-05-22T08:28:38Z   False
# 110                      Antrag Schuldspruch  2017-05-10T07:42:51Z   False
# 111                        Antrag Freispruch  2018-01-24T07:45:11Z   False
# 112                  Dispositiv allgemein SB  2018-03-14T08:38:52Z   False
# 113                  Dispositiv allgemein SB  2018-01-17T07:46:20Z   False
# 114        Antrag Schuldspruch (ausführlich)  2018-07-27T07:48:46Z   False
# 115                      Antrag Schuldspruch  2018-05-16T07:08:54Z   False
# 116                      Antrag Schuldspruch  2018-07-18T08:29:53Z   False
# 117                  Dispositiv allgemein SB  2018-07-12T07:46:51Z   False
# 118                  Dispositiv allgemein SB  2018-09-26T08:11:49Z   False
# 119                  Dispositiv allgemein SB  2018-07-05T07:33:01Z   False
# 120                  Dispositiv allgemein SB  2018-09-26T08:10:56Z   False
# 121        Antrag Schuldspruch (ausführlich)  2019-05-02T08:52:41Z   False
# 122                  Dispositiv allgemein SB  2018-06-13T06:52:17Z   False
# 123                  Dispositiv allgemein SB  2019-01-16T08:21:15Z   False
# 124                      Antrag Schuldspruch  2018-08-22T08:06:42Z   False
# 125                        Antrag Freispruch  2019-07-03T08:04:44Z   False
# 126                  Dispositiv allgemein SB  2019-06-19T08:38:16Z   False
# 127                      Antrag Schuldspruch  2019-06-26T06:54:49Z   False
#
#                                                 punish  \
# 2                                                  NaN
# 3                                                  NaN
# 4     Der Angeklagte wird bestraft mit 17 Monaten F...
# 6     Der Angeklagte wird unter Einbezug der widerr...
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...
# 9     Der Angeklagte wird bestraft mit 36 Monaten F...
# 10    Der Angeklagte wird bestraft mit 7 ½ Jahren F...
# 12                                                 NaN
# 13                                                 NaN
# 15    Der Angeklagte wird bestraft mit 28 Monaten F...
# 16    Februar 2006 ausgefällte, bedingte \n\nFreihe...
# 17    März 2009 ausgefällten Freiheitsstrafe rück-\...
# 18                                                 NaN
# 19    Der Angeklagte wird bestraft mit 6 Jahren Fre...
# 20    Der Angeklagte wird bestraft mit 18 Monaten F...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24    Der Angeklagte wird bestraft mit 10 Jahren Fr...
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28    Der Beschuldigte wird unter Einbezug des wide...
# 29                                                 NaN
# 30    Der Beschuldigte wird bestraft mit 4 ½ Jahren...
# 31                                                 NaN
# 32                                                 NaN
# 33    Der Beschuldigte wird bestraft mit 4 Jahren F...
# 34                                                 NaN
# 35                                                 NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                                                punish1 exact_punish  \
# 2    _____ wird bestraft mit 18 Monaten Freiheitsst...          NaN
# 3                                                  NaN          NaN
# 4     Der Beschuldigte wird bestraft mit 2 1/2 Jahr...   17 Monaten
# 6                                                  NaN   27 Monaten
# 8     Der Beschuldigte wird bestraft mit 12 Jahren ...    12 Jahren
# 9                                                  NaN   36 Monaten
# 10                                                 NaN     336 Tage
# 12                                                 NaN          NaN
# 13                                                 NaN          NaN
# 15                                                 NaN   28 Monaten
# 16                                                 NaN    8 Monaten
# 17                                                 NaN          NaN
# 18    Der Beschuldigte wird bestraft mit 3 ¼ Jahren...          NaN
# 19                                                 NaN     6 Jahren
# 20                                                 NaN   18 Monaten
# 21    Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 22    Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 23                                                 NaN          NaN
# 24    Der Angeklagte wird bestraft mit 14 Jahren Fr...    10 Jahren
# 25    Der Beschuldigte wird bestraft mit 16 Jahren ...          NaN
# 26    Der Beschuldigte wird bestraft mit 5 Jahren u...          NaN
# 27                                                 NaN          NaN
# 28    Oktober 2009 für eine Reststrafe von 37 Tagen...     37 Tagen
# 29    März 2009 für eine Freiheitsstrafe von 136 Ta...          NaN
# 30                                                 NaN        1 Tag
# 31    Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 32    Der Beschuldigte wird bestraft mit 2 Jahren F...          NaN
# 33    Der Beschuldigte wird bestraft mit 3 1/3 Jahr...     4 Jahren
# 34    Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 35    Der Beschuldigte wird bestraft mit 3 ½ Jahren...          NaN
# ..                                                 ...          ...
# 98    Der Beschuldigte wird bestraft mit 24 Monaten...          NaN
# 99    Der Beschuldigte wird bestraft mit 32 Monaten...          NaN
# 100   123 StGB von einem Tagessatz Geldstrafe bis z...          NaN
# 101   Januar 2013 ausgefällten Freiheitsstrafe wird...          NaN
# 102                                                NaN          NaN
# 103   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 104   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 105   Der Beschuldigte wird bestraft mit 9 Jahren F...          NaN
# 106   Der Beschuldigte wird bestraft mit 21 Monaten...          NaN
# 107   45 StGB); Analoges gilt für die bedingte \n\n...          NaN
# 108    Der Beschuldigte wird bestraft mit einer Fre...          NaN
# 109   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 110   Der Beschuldigte wird bestraft mit 4 Monaten ...          NaN
# 111                                                NaN          NaN
# 112   Der Vollzug der Freiheitsstrafe wird aufgesch...          NaN
# 113                                                NaN          NaN
# 114                                                NaN          NaN
# 115   Die obere Grenze des Strafrahmens sei zehn Ja...          NaN
# 116   Der Beschuldigte wird bestraft mit 4 Jahren u...          NaN
# 117   Der Beschuldigte wird bestraft mit 44 Monaten...          NaN
# 118                                                NaN          NaN
# 119   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 120   Der Beschuldigte wird bestraft mit 30 Monaten...          NaN
# 121   Die Beschuldigte wird bestraft mit 16 Monaten...          NaN
# 122  _____ wird bestraft mit 3 Jahren Freiheitsstra...          NaN
# 123   Der Beschuldigte wird bestraft mit einer Frei...          NaN
# 124   Der Beschuldigte wird bestraft mit 4 Jahren F...          NaN
# 125   Der Beschuldigte wird bestraft mit 3 Jahren F...          NaN
# 126   Der Beschuldigte wird bestraft mit 4 ⅔ Jahren...          NaN
# 127   Der Beschuldigte sei – zusätzlich zur erstins...          NaN
#
#     exact_punish1 number_punish number_punish1
# 2      18 Monaten           NaN             18
# 3             NaN           NaN            NaN
# 4        2 Jahren            17              2
# 6             NaN            27            NaN
# 8       12 Jahren            12             12
# 9             NaN            36            NaN
# 10            NaN           336            NaN
# 12            NaN           NaN            NaN
# 13            NaN           NaN            NaN
# 15            NaN            28            NaN
# 16            NaN             8            NaN
# 17            NaN           NaN            NaN
# 18       171 Tage           NaN            171
# 19            NaN             6            NaN
# 20            NaN            18            NaN
# 21     13 Monaten           NaN             13
# 22     30 Monaten           NaN             30
# 23            NaN           NaN            NaN
# 24      14 Jahren            10             14
# 25      16 Jahren           NaN             16
# 26       5 Jahren           NaN              5
# 27            NaN           NaN            NaN
# 28       37 Tagen            37             37
# 29      136 Tagen           NaN            136
# 30            NaN             1            NaN
# 31       3 Jahren           NaN              3
# 32       2 Jahren           NaN              2
# 33       3 Jahren             4              3
# 34       4 Jahren           NaN              4
# 35       554 Tage           NaN            554
# ..            ...           ...            ...
# 98     24 Monaten           NaN             24
# 99     32 Monaten           NaN             32
# 100      123 StGB           NaN            123
# 101           NaN           NaN            NaN
# 102           NaN           NaN            NaN
# 103    22 Monaten           NaN             22
# 104      4 Jahren           NaN              4
# 105      9 Jahren           NaN              9
# 106    21 Monaten           NaN             21
# 107       45 StGB           NaN             45
# 108    40 Monaten           NaN             40
# 109    24 Monaten           NaN             24
# 110     4 Monaten           NaN              4
# 111           NaN           NaN            NaN
# 112           NaN           NaN            NaN
# 113           NaN           NaN            NaN
# 114           NaN           NaN            NaN
# 115           NaN           NaN            NaN
# 116      4 Jahren           NaN              4
# 117    44 Monaten           NaN             44
# 118           NaN           NaN            NaN
# 119    30 Monaten           NaN             30
# 120    30 Monaten           NaN             30
# 121    16 Monaten           NaN             16
# 122      3 Jahren           NaN              3
# 123      4 Jahren           NaN              4
# 124      4 Jahren           NaN              4
# 125      3 Jahren           NaN              3
# 126           NaN           NaN            NaN
# 127      2 Jahren           NaN              2
#
# [120 rows x 13 columns]

# %%
df_new.to_csv('data_with_exact_numbers.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# author             object
# judgement          object
# judgement1         object
# judgement2         object
# title              object
# year               object
# guilty               bool
# punish             object
# punish1            object
# exact_punish       object
# exact_punish1      object
# number_punish     float64
# number_punish1    float64
# dtype: object

# %% [markdown]
# ## Read in dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('data_with_exact_numbers.csv')

# %%
import numpy as np

# %%
df.loc[df.exact_punish.str.contains('Jahr', na=False), 'cleaned_number_in_months'] = df.number_punish.mul(12)
df.loc[df.exact_punish.str.contains('Tag', na=False), 'cleaned_number_in_months'] = df.number_punish.div(30)
df.loc[df.exact_punish.str.contains('Monat', na=False), 'cleaned_number_in_months'] = df.number_punish
df.head()
# Out:
#    Unnamed: 0                author  \
# 0           2   lic.iur. S. Janssen
# 1           3          Dr. Bischoff
# 2           4    lic. iur. N. Burri
# 3           6  lic.iur. C. Semadeni
# 4           8             T. Müller
#
#                                            judgement  \
# 0  Es wird beschlossen: \n\n1. Es wird festgestel...
# 1                                                 \n
# 2  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 3                                                 \n
# 4  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                           judgement1  \
# 0  Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 1                                                 \n
# 2  Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 3                                                 \n
# 4  Es wird erkannt: \n\n1. Der Beschuldigte wird ...
#
#                                           judgement2  \
# 0                                                 \n
# 1  Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 2  Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 3  Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 4  Das Gericht erkennt: \n\n1. Der Beschuldigte i...
#
#                                      title                  year  guilty  \
# 0  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 1                  Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 2  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 3  Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 4                  Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
#
#                                               punish  \
# 0                                                NaN
# 1                                                NaN
# 2   Der Angeklagte wird bestraft mit 17 Monaten F...
# 3   Der Angeklagte wird unter Einbezug der widerr...
# 4   Der Beschuldigte wird bestraft mit 12 Jahren ...
#
#                                              punish1 exact_punish  \
# 0  _____ wird bestraft mit 18 Monaten Freiheitsst...          NaN
# 1                                                NaN          NaN
# 2   Der Beschuldigte wird bestraft mit 2 1/2 Jahr...   17 Monaten
# 3                                                NaN   27 Monaten
# 4   Der Beschuldigte wird bestraft mit 12 Jahren ...    12 Jahren
#
#   exact_punish1  number_punish  number_punish1  cleaned_number_in_months
# 0    18 Monaten            NaN            18.0                       NaN
# 1           NaN            NaN             NaN                       NaN
# 2      2 Jahren           17.0             2.0                      17.0
# 3           NaN           27.0             NaN                      27.0
# 4     12 Jahren           12.0            12.0                     144.0

# %%
df.loc[df.exact_punish1.str.contains('Jahr', na=False), 'cleaned_number_in_months1'] = df.number_punish1.mul(12)
df.loc[df.exact_punish1.str.contains('Tag', na=False), 'cleaned_number_in_months1'] = df.number_punish1.div(30)
df.loc[df.exact_punish1.str.contains('Monat', na=False), 'cleaned_number_in_months1'] = df.number_punish1
df.head()
# Out:
#    Unnamed: 0                author  \
# 0           2   lic.iur. S. Janssen
# 1           3          Dr. Bischoff
# 2           4    lic. iur. N. Burri
# 3           6  lic.iur. C. Semadeni
# 4           8             T. Müller
#
#                                            judgement  \
# 0  Es wird beschlossen: \n\n1. Es wird festgestel...
# 1                                                 \n
# 2  Es wird beschlossen: \n\n1. Auf die Berufung d...
# 3                                                 \n
# 4  Es wird beschlossen: \n\n1. Es wird festgestel...
#
#                                           judgement1  \
# 0  Es wird erkannt: \n\n1. Der Angeklagte A._____...
# 1                                                 \n
# 2  Es wird erkannt: \n \n\n1. Der Beschuldigte is...
# 3                                                 \n
# 4  Es wird erkannt: \n\n1. Der Beschuldigte wird ...
#
#                                           judgement2  \
# 0                                                 \n
# 1  Das Gericht erkennt: \n\n1. Der Angeklagte B._...
# 2  Das Gericht erkennt: \n\n1. Der Angeklagte C._...
# 3  Das Gericht erkennt:  \n\n1. Der Angeklagte A....
# 4  Das Gericht erkennt: \n\n1. Der Beschuldigte i...
#
#                                      title                  year  guilty  \
# 0  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:33:06Z   False
# 1                  Dispositiv allgemein SB  2014-10-30T20:45:26Z   False
# 2  Antragsformular/Dispositiv allgemein SB  2014-10-29T19:45:15Z   False
# 3  Antragsformular/Dispositiv allgemein SB  2014-10-30T20:46:08Z   False
# 4                  Dispositiv allgemein SB  2014-10-29T18:08:22Z   False
#
#                                               punish  \
# 0                                                NaN
# 1                                                NaN
# 2   Der Angeklagte wird bestraft mit 17 Monaten F...
# 3   Der Angeklagte wird unter Einbezug der widerr...
# 4   Der Beschuldigte wird bestraft mit 12 Jahren ...
#
#                                              punish1 exact_punish  \
# 0  _____ wird bestraft mit 18 Monaten Freiheitsst...          NaN
# 1                                                NaN          NaN
# 2   Der Beschuldigte wird bestraft mit 2 1/2 Jahr...   17 Monaten
# 3                                                NaN   27 Monaten
# 4   Der Beschuldigte wird bestraft mit 12 Jahren ...    12 Jahren
#
#   exact_punish1  number_punish  number_punish1  cleaned_number_in_months  \
# 0    18 Monaten            NaN            18.0                       NaN
# 1           NaN            NaN             NaN                       NaN
# 2      2 Jahren           17.0             2.0                      17.0
# 3           NaN           27.0             NaN                      27.0
# 4     12 Jahren           12.0            12.0                     144.0
#
#    cleaned_number_in_months1
# 0                       18.0
# 1                        NaN
# 2                       24.0
# 3                        NaN
# 4                      144.0

# %%
df['year'] = df.year.str.extract("(^\d\d\d\d)")

# %%
df1 = df[['year','title', 'cleaned_number_in_months', 'cleaned_number_in_months1']]
df1['months'] = df1['cleaned_number_in_months']
df1['months1'] = df1['cleaned_number_in_months1']
df1.head()
df1 = df1[['year','title', 'months', 'months1']]
df1.head()
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    year                                    title  months  months1
# 0  2014  Antragsformular/Dispositiv allgemein SB     NaN     18.0
# 1  2014                  Dispositiv allgemein SB     NaN      NaN
# 2  2014  Antragsformular/Dispositiv allgemein SB    17.0     24.0
# 3  2014  Antragsformular/Dispositiv allgemein SB    27.0      NaN
# 4  2014                  Dispositiv allgemein SB   144.0    144.0

# %%
df1.months[(df1.months == 'Nan')] = df1['months1']
df1.head()
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#    year                                    title  months  months1
# 0  2014  Antragsformular/Dispositiv allgemein SB     NaN     18.0
# 1  2014                  Dispositiv allgemein SB     NaN      NaN
# 2  2014  Antragsformular/Dispositiv allgemein SB    17.0     24.0
# 3  2014  Antragsformular/Dispositiv allgemein SB    27.0      NaN
# 4  2014                  Dispositiv allgemein SB   144.0    144.0

# %%
df1.months1.isna().sum()
# Out:
# 44

# %%
df1.months.isna().sum()
# Out:
# 98

# %%
df = df1[['year', 'months1']]
df.head()
# Out:
#    year  months1
# 0  2014     18.0
# 1  2014      NaN
# 2  2014     24.0
# 3  2014      NaN
# 4  2014    144.0

# %%
df = df[np.isfinite(df['months1'])]
df
df.to_csv('data_cleaned_1207.csv')

# %%
df.head()
# Out:
#     year  months1
# 0   2014     18.0
# 2   2014     24.0
# 4   2014    144.0
# 12  2014      5.7
# 15  2014     13.0

# %% [markdown]
# ### Some analysis with the numbers

# %%
df.groupby(by='year').months1.describe()
# Out:
#       count       mean        std        min   25%   50%        75%    max
# year
# 2014   36.0  49.898148  58.494940   0.733333  17.0  25.5  51.000000  216.0
# 2015    8.0  48.375000  63.365926  14.933333  21.5  27.0  36.016667  204.0
# 2016   11.0  37.818182  21.752325  14.000000  27.0  36.0  39.000000   96.0
# 2017    5.0  41.000000  40.607881   4.000000  21.0  24.0  48.000000  108.0
# 2018   10.0  55.400000  57.170700  22.000000  30.5  40.0  48.000000  216.0
# 2019    6.0  31.333333  11.977757  16.000000  24.0  30.0  39.000000   48.0

# %% [markdown]
# ### Starting with the graphs

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set()

matplotlib.rcParams['pdf.fonttype'] = 42

# %%
# df['year'] = df['year'].astype(str)

# %%
df['year'] = df['year'].astype(int)

# %%
len(df.months1)
# Out:
# 76

# %%
df.year
# Out:
# 0          2014
# 2          2014
# 4          2014
# 12         2014
# 15         2014
# 16         2014
# 18         2014
# 19         2014
# 20         2014
# 22         2014
# 23         2014
# 25         2014
# 26         2014
# 27         2014
# 28         2014
# 29         2014
# 34         2014
# 36         2014
# 38         2014
# 39         2014
# 40         2014
# 42         2014
# 47         2014
# 49         2014
# 50         2014
# 51         2014
# 52         2014
# 53         2014
# 54         2014
# 55         2014
#            ...
# 76         2016
# 77         2016
# 78         2016
# 79         2016
# 81         2016
# 82         2016
# 83         2016
# 85         2016
# 88         2017
# 89         2017
# 90         2016
# 91         2018
# 95         2018
# 96         2018
# 97         2017
# 98         2017
# 100        2019
# 101        2019
# 102        2017
# 108        2018
# 109        2018
# 111        2018
# 112        2018
# 113        2019
# 114        2018
# 115        2019
# 116        2018
# 117        2019
# 119        2019
# months1      24
# Name: year, Length: 77, dtype: object

# %%
line1 = pd.DataFrame([2013,2014,2015,2016,2017,2018,2019,2020])
line1["months1"] = [12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0]
line1["year"] = line1[0]

# %%
line1.year = line1.year.astype(int)

# %%
line1.year
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# 4    2018
# 5    2019
# Name: year, dtype: int32

# %%
#plt.figure(figsize=(15,8))
sns.set_style("ticks")

fig, ax = plt.subplots(figsize=(8,10))

ax.set_ylim([0,250])

ax.set_xlim(left=2013,right=2020)

#df.plot(y='months1', x='year',alpha=0.5,color="dodgerblue", ax=ax, kind="scatter")
sns.swarmplot(data=df,y='months1', x='year',alpha=0.7,color="dodgerblue", size=8)

#line1.plot(x="year",y="months1", ax=ax, color="red", legend=None)
# sns.lineplot(data=line1,x="year",y="months1", color="red", legend=None)

# plt.show(p1,p2)

plt.savefig("second_graph_idea.pdf")

# rape in Switzerland: 1 bis 10 Jahre; 30 bis 300 months

# grid = sns.JointGrid(df.year, df.months1, space=2, size=6, ratio=50)

# %%
sns.set_style("ticks")

fig, ax = plt.subplots(figsize=(8,10))

ax.set_ylim([0,250])

ax.set_xlim(left=2013,right=2020)

sns.lineplot(data=line1,x="year",y="months1", color="red", legend=None)

plt.savefig("line.pdf")
